# %% [markdown]
# <a href="https://colab.research.google.com/github/fmaina1/nlp-fellowship/blob/main/Copy_of_Neural_Language_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Word Embeddings
# Word embeddings were proposed by  [Bengio et. al. (2001, 2003)](https://www.jmlr.org/papers/volume3/bengio03a/bengio03a.pdf)
#
# From the dataset, the neural network would identify the words with similar meaning, but also preserve the words semantic (properties of word boy - young, male, human) and syntatic (word order, noun, grammatic relationship) propoerties.
#
# The cat is walking in the bedroom
#
# A dog was running in a room
#
# The cat is running in a room
#
# A dog is walking in a bedroom
#
# The dog was walking in the room
#
# This neural network has three components:
#
# 1. An embedding layer that generates word embedding, and the parameters are shared across words.
#   * It’s a lookup table, given the index, it will return the corresponding vector.
#   * The vector representation indicated the weighted matrix is initialized as random values and will be updated by backpropagation
# 2. A hidden layer of one or more layers, which introduces non-linearity to the embeddings.
# 3. A softmax function that produces probability distribution over all the words in the vocabulary.
#
# The words would be represented in a dense vector
# * dog [0.2,0.5,-1.5,2.4] (length of vector is set as a parameter)

# %% [markdown]
# ## Step 1: Get the dataset

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
import pandas as pd
path = '/content/gdrive/MyDrive/NLP_Fellowship_2022/Notebooks/Week 3/data' # Enter your path
os.chdir(path)
# !ls
# Out:
#  en.bin			   'IMDB Dataset.csv'   model.bin	 text.txt
#  Eng_Kin-Paralleldata.csv   model	        model_cbow.bin

# %%
dataset = pd.read_csv('IMDB Dataset.csv')
dataset.head(100)
# Out:
#                                                review sentiment
# 0   One of the other reviewers has mentioned that ...  positive
# 1   A wonderful little production. <br /><br />The...  positive
# 2   I thought this was a wonderful way to spend ti...  positive
# 3   Basically there's a family where a little boy ...  negative
# 4   Petter Mattei's "Love in the Time of Money" is...  positive
# ..                                                ...       ...
# 95  Daniel Day-Lewis is the most versatile actor a...  positive
# 96  My guess would be this was originally going to...  negative
# 97  Well, I like to watch bad horror B-Movies, cau...  negative
# 98  This IS the worst movie I have ever seen, as w...  negative
# 99  I have been a Mario fan for as long as I can r...  positive
#
# [100 rows x 2 columns]

# %%
dataset.describe()
# Out:
#                                                    review sentiment
# count                                               50000     50000
# unique                                              49582         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %%
english_text = list(set(dataset['review'])) #Depends on your data. Change code
english_text = english_text[:5000]
print(len(english_text))
# Out:
# 5000

# %%
import re
def preprocess(text):
    text = text.lower()
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               "]+", flags=re.UNICODE)
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    html_pattern = re.compile('<.*?>')
    text = emoji_pattern.sub(r'', text)
    text = url_pattern.sub(r'', text)
    text = html_pattern.sub(r'', text)
    text = re.sub(r"[^\w\d'\s]+", ' ', text)

    return text

# %%
processed_english_text = []
for sent in english_text:
  processed_english_text.append(preprocess(sent))

print(len(processed_english_text))
processed_english_text[:5]
# Out:
# 5000
# ['was it foreshadowing when tori complained that her first boyfriend was treating her like a robot  and then her new boyfriend  the murderer  turned out to be a designer of artificial intelligence  i think so  scenes to make you squeal with delight  montages galore  a strip tease in a kimono  what do you call it when you seductively put clothes on  instead of take them off  and a climactic battle on skis  definitely tune in for the beginning and end  but you can grab a sandwich during the second act when all the plot is happening  is it better than co ed call girl  nah  does tori ever make it to paradise  or out of the snow  even  nope ',
#  "the script for  scary movie 2  just wasn't ready to go  this is a problem with the film that is blatantly evident  to the actors and the audience alike  director keenan ivory wayans  and many of the actors are funny people  and so the movie isn't completely humorless  to their credit  the film has several funny moments  but as a whole   scary movie 2  is not even close to being as clever and amusing as the original the first  scary movie  was a laugh a minute film  it turned the smallest subtleties of the slasher film genre into comedic gold  the humor in  scary movie 2  is as heavy handed as it is un original  they even miss obvious opportunities for parody  two of the movies stars are former cast members of  beverly hills 90210  and this was a show that was begging to be parodied  in the final analysis   scary movie 2  is like a fine bottle of wine that was opened far too soon  the script needed a lot more time to age  2 stars out of 5 ",
#  "the only print of chikamatus monogatari i've been able to find was abysmal   i almost couldn't watch it  which is a shame as this is among the greatest mizoguchi films  the story   which i believe had been done before and since by other japanese directors   is a bit straighter than my favorite mizoguchi films  sansho the bailiff and ugetsu monogatari  and is essentially a tale of tragic romance  in this case a transgressive romance that crosses strict class boundaries  as always with mizoguchi  there is an exquisitely expressed tone of defiance  and   bad print aside   i was very pleased  as with all of mizoguchi's films  i'm eagerly awaiting a restored dvd release   whenever that may come ",
#  "prom night is about a girl named donna  brittany snow  who is being chased by a psycho killer trying to kill her at her prom night  and by doing so killing her family  friends  and her enemies  now before i begin let me say have you been tired of pg 13 horror movies that haven't been scary lately  are you tired of stupid girl dialog 'oh my god' and talking about girlish things  and are you really tired of girls in relationships and then crying  and the last thing are you tired of the us remaking asian  japanese  and chinese films  that pretty much sums up prom night but i'm still not done with the review the only reason to see 'prom night' is to crack a laugh at the kills  if not  don't see prom night  you never see the kills an only hear screaming and you see some blood on the wall  and by the way the deaths are repeating like 24 7  so not only aren't they scary but it's obnoxious  by the time i met the cast i think i was ready to hurl  too much girl talk  too much guy talk  and lots of 'oh my gosh  it's our prom'  i understand it's fun but seriously is it too much to ask not to concentrate  if i were to put prom night on the list of worst films of 2008 without seeing the other films i'd be the first one too  i'm not going to be surprised if it gets released on dvd for cheap and quick  seriously don't spend your money or the time for dull acting  cheap scares  and a 'night to die for' when watching the film 1 star out of 10   p s  if i could give the film zero stars i would ",
#  "i mean of all the obscure  overlooked  low budget horror movies waiting to be re discovered in a dvd release  why pick the forest  i love ultra low budget direct to home video or other alternative release horror  i love 80s hacker horror  i love backwoods slashers with fools wandering off into the night to be chased  murdered and eaten by psychopaths  i am all for the idea of non professionals working on a horror movie as a way to maybe break into the industry or just making a movie because they want to make one  i am all for using found public locations  non actors  no name talent behind the camera and in the studio  no problem  the most evocative image from the forest is it's opening shot of a couple walking in the distance across a forest into the woods  we see them as tiny  vulnerable creatures entering a dank gloomy world where humans may not be the top of the food chain or most feared predator  then the film takes a dive   never recovers   we briefly meet the backpacking couple just as they realize that they are being stalked  they get separated  both are butchered  and then we meet the movie's protagonists as they drive their car in a traffic jam  they meet up with their respective mates and decide to take a camping trip  sounds of snoring fill the room as people who came over to watch a movie fiddle with their cell phones text messaging people not there telling them how much the movie sucks this film is too slow  this movie is too boring  and this movie is too talky  which wouldn't be such a bad thing if the writers had given the people something to say other than the most stupid  asinine and unnecessary things  you know your horror movie is in trouble when the character with the most interesting lines is the droopy faced park ranger who warns everyone away from the cannibal woods  and speaking of these  woods  they look about as far away from civilization as the overgrown vacant lot behind the soccer fields  only with bigger rocks and a stream flowing through it  there are impressive shots of the forest primeval  but no real sense of being out in the middle of it  if any one of the characters just sat down on the trail and waited long enough someone would amble by what is worse about the film is that it fails to generate any human interest  i don't know who these couples are and don't care what happens to them  the hermit cannibal slasher guy is uninteresting even when pretending to saw freshly cooked meat off the leg of one of his victims to serve grisly bites to her boyfriend  who just happens to seek shelter in his cave  the irony of which is the epitome of  underwhelming  coupled with a deliberately ominous synthesizer music score  cinematography that suspiciously looks like someone strapped a camera on a dog and it follow people's movements  a lack of appreciable gore  nudity  lurid thrills and unwholesome atmosphere and what we have here is a horror movie that isn't even as frightening as a pbs educational tv show about how magnets work i don't mean to  dish it out  to the people behind this film  since they obviously went into the project with next to nothing  did not push themselves to be creative and ended up with just another boring movie about some maggot chasing women through the woods with a knife  there is nothing wrong with that concept  what is wrong is the unimaginative and utterly pedestrian way this was executed  right down to the utterly pointless conclusion when the film simply peters out at about the 80 minute mark  the best thing that you can say about the forest is that it is over relatively quickly and there isn't much to command a repeat screening   hence my confusion at why anyone would feel the need for a dvd release  it was fine as a prism video rental years oddity  as a dvd it will be  5 99 rack fare inside a month of hitting the shelves  there is little or no urgency to see the film  unless you are considering making your own ultra low budget backwoods hacker set in a public park where ...

# %% [markdown]
# ## Step 2: index the words

# %%
UNK_symbol = "<UNK>"
all_words = set([UNK_symbol])
word_to_index = {}
index_to_word = {}
for sentence in processed_english_text:
  words = [token for token in sentence.split() ]
  all_words.update(words)

for index,value in enumerate(all_words):
  word_to_index[value] = index
  index_to_word[index] = value
  
n_class = len(word_to_index) # number of Vocabulary

print(n_class)
# Out:
# 43678

# %%
sorted(word_to_index, key=word_to_index.get)[10:40]
# Out:
# ['heritage',
#  'walkie',
#  'morvern',
#  'critic',
#  '1997',
#  'rotting',
#  'sheba',
#  'keeler',
#  'francesco',
#  'snatched',
#  'grovelling',
#  'eccleston',
#  'ultraviolet',
#  'privlages',
#  'ample',
#  'partition',
#  "hosseini's",
#  'passable',
#  "bunny's",
#  'medieval',
#  'janis',
#  'kiwi',
#  "squeeze's",
#  'athenia',
#  'decorating',
#  'frantz',
#  'inventor',
#  'ontological',
#  'phoenix',
#  "'wiedzmin'"]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader
import time

torch.cuda.empty_cache()
if torch.cuda.is_available():
  device = torch.device("cuda")
else:
  device = torch.device("cpu")

# %%
def create_input_target(list_sentences):
  input_batch = []
  target_batch = []

  for sen in list_sentences:
      word = sen.split() # space tokenizer
      input = [word_to_index[n] for n in word[:-1]] # create (1~n-1) as input (every word in the sentence except the last word)
      target = word_to_index[word[-1]] # create (n) as target, We usually call this 'casual language model'

      input_batch.append(torch.tensor(input))
      target_batch.append(target)

  return input_batch,target_batch

# %% [markdown]
# ## Build the model

# %%
#Use this cell for testing the shape of input when passed through different layers
# X =nn.Embedding(n_class, 2)(input_batch)
# X=X.view(-1, 2 * 2)
# #tanh = torch.tanh(nn.Parameter(torch.ones(2)) + nn.Linear(2 * 2, 2, bias=False)(X))
# nn.Parameter(torch.ones(2))
# #nn.Linear(2 * 2, 2, bias=False)
# # # nn.Linear(2, n_class, bias=False)
# # # nn.Linear(2 * 2, n_class, bias=False)
# # # nn.Parameter(torch.ones(n_class))
# # #torch.LongTensor(input_batch[0])
# #tanh.shape

# %%
class NNLM(nn.Module):
    def __init__(self):
        super(NNLM, self).__init__()
        self.embeddings = nn.Embedding(n_class, m)
        self.hidden1 = nn.Linear(n_step * m, n_hidden, bias=False)
        self.ones = nn.Parameter(torch.ones(n_hidden))
        self.hidden2 = nn.Linear(n_hidden, n_class, bias=False)
        self.hidden3 = nn.Linear(n_step * m, n_class, bias=False)
        self.bias = nn.Parameter(torch.ones(n_class))

    def forward(self, X):
        X = self.embeddings(X) # X : [batch_size, n_step, m]
        
        #X = X.flatten()
        X = X.view(-1, n_step * m) # [batch_size, n_step * m] first layer (-1 flattens the tensor)
        
        tanh = torch.tanh(self.ones + self.hidden1(X)) # [batch_size, n_hidden] pass embedded layer through first hidden layet and add bias. The result is passed through tanh function
        
        output = self.bias + self.hidden3(X) + self.hidden2(tanh) # [batch_size, n_class]
        return output

if __name__ == '__main__':
  n_step = 2 # number of steps, n-1 in paper
  n_hidden = 2 # number of hidden size, h in paper
  m = 10 # embedding size, m in paper,( batch size)
  
  gpu = 0
  input_batch,target_batch = create_input_target(processed_english_text)
  input_batch = torch.LongTensor(pad_sequence(input_batch))
  train_loader = DataLoader(input_batch, batch_size = 10, num_workers = 1)
  
  target_batch = torch.LongTensor(target_batch)
  dev_loader = DataLoader(target_batch, batch_size = 10, num_workers = 1)
  

  model = NNLM()
  model.cuda(gpu)

  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
for epoch in range(50):
    st = time.time()
    
    for it, data_tensor in enumerate(train_loader):  
      
      context_tensor = data_tensor[:,0:2]
      target_tensor = data_tensor[:,2]

      context_tensor, target_tensor = context_tensor.cuda(gpu), target_tensor.cuda(gpu)

      optimizer.zero_grad()
      output = model(context_tensor)

      #acc = get_accuracy_from_log_probs(output, target_tensor)

      # output : [batch_size, n_class], target_batch : [batch_size]
      loss = criterion(output, target_tensor)
      if (epoch + 1) % 5 == 0:
          print('Epoch:', '%04d' % (epoch + 1), 'cost =', '{:.6f}'.format(loss),'output size: ',output.size)

      loss.backward()
      optimizer.step()

      if it % 500 == 0: 
        print("Training Iteration {} of epoch {} complete. Loss: {}; Time taken (s): {}".format(it, epoch, loss.item(), (time.time()-st)))
        st = time.time()

      
      # set best model path
      best_model_path = 'model/best_model_{}.dat'.format(epoch)
      # saving best model
      torch.save(model.state_dict(), best_model_path)
# Out:
# Training Iteration 0 of epoch 0 complete. Loss: 10.678858757019043; Time taken (s): 0.09085702896118164
# Training Iteration 0 of epoch 1 complete. Loss: 10.550771713256836; Time taken (s): 0.03574514389038086
# Training Iteration 0 of epoch 2 complete. Loss: 10.39503288269043; Time taken (s): 0.03457760810852051
# Training Iteration 0 of epoch 3 complete. Loss: 10.09555721282959; Time taken (s): 0.03358769416809082
# Epoch: 0005 cost = 9.770510 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Training Iteration 0 of epoch 4 complete. Loss: 9.770509719848633; Time taken (s): 0.0382232666015625
# Epoch: 0005 cost = 9.982875 output size:  <built-in method size of Tensor object at 0x7f61d86f5650>
# Epoch: 0005 cost = 9.821010 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 9.596792 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 10.018030 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 9.698812 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 10.024698 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 9.431256 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 9.112206 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 8.910055 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 9.036837 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 8.240771 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 1.861293 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 1.882751 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 1.990819 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 1.800810 output size:  <built-in method size of Tensor object at 0x7f61d86f5a70>
# Epoch: 0005 cost = 1.923459 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 2.502638 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 0.015423 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.015013 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.014651 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 0.014328 output size:  <built-in method size of Tensor object at 0x7f61d86f5cb0>
# Epoch: 0005 cost = 0.014041 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.013784 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.013554 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.013347 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.013161 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.012992 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.012840 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.012702 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 0.012575 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.012460 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.012354 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.012257 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.012169 output size:  <built-in method size of Tensor object at 0x7f61d86f5890>
# Epoch: 0005 cost = 0.012087 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.012011 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.011941 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.011876 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 0.011814 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.011758 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.011704 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 0.011654 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.011607 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.011562 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 0.011519 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.011479 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.011441 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.011404 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.011369 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.011335 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.011303 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.011271 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.011241 output size:  <built-in method size of Tensor object at 0x7f61d86f59b0>
# Epoch: 0005 cost = 0.011211 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.011183 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.011155 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 0.011128 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.011101 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.011075 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.011050 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 0.011024 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.011000 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.010976 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.010952 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.010929 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 0.010906 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.010883 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.010860 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.010838 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0005 cost = 0.010816 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.010794 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.010772 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.010750 output size:  <built-in method size of Tensor object at 0x7f61d86f5cb0>
# Epoch: 0005 cost = 0.010729 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 0.010708 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.010686 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 0.010665 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0005 cost = 0.010644 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.010624 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.010603 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.010582 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 0.010562 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.010542 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.010521 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0005 cost = 0.010501 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.010481 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.010461 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0005 cost = 0.010441 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.010421 output size:  <built-in method size of Tensor object at 0x7f61d86f55f0>
# Epoch: 0005 cost = 0.010401 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.010381 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.010362 output size:  <built-in method size of Tensor object at 0x7f61d86f5890>
# Epoch: 0005 cost = 0.010342 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.010322 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0005 cost = 0.010303 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.010283 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.010264 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0005 cost = 0.010245 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.010226 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.010206 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.010187 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.010168 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.010149 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.010130 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.010111 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.010092 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0005 cost = 0.010074 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.010055 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.010036 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0005 cost = 0.010018 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.009999 output size:  <built-in method size of Tensor object at 0x7f61d86f5890>
# Epoch: 0005 cost = 0.009981 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0005 cost = 0.009962 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.009943 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.009925 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.009907 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.009889 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.009870 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.009852 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.009834 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0005 cost = 0.009815 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.009798 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.009779 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.009762 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.009743 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0005 cost = 0.009726 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.009708 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.009690 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.009672 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0005 cost = 0.009655 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0005 cost = 0.009637 output size:  <built-in method size of Tensor object at 0x7f61d86f5890>
# Epoch: 0005 cost = 0.009619 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0005 cost = 0.009602 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0005 cost = 0.009584 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0005 cost = 0.009567 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0005 cost = 0.009549 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Training Iteration 0 of epoch 5 complete. Loss: 9.431051254272461; Time taken (s): 0.03803563117980957
# Training Iteration 0 of epoch 6 complete. Loss: 9.079887390136719; Time taken (s): 0.0357365608215332
# Training Iteration 0 of epoch 7 complete. Loss: 8.717710494995117; Time taken (s): 0.03467392921447754
# Training Iteration 0 of epoch 8 complete. Loss: 8.344670295715332; Time taken (s): 0.03625679016113281
# Epoch: 0010 cost = 7.960935 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Training Iteration 0 of epoch 9 complete. Loss: 7.960934638977051; Time taken (s): 0.03980135917663574
# Epoch: 0010 cost = 8.215748 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0010 cost = 7.857134 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0010 cost = 7.816024 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0010 cost = 8.253038 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0010 cost = 7.850429 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0010 cost = 8.136072 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0010 cost = 7.454252 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 7.048335 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0010 cost = 7.037008 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0010 cost = 7.027558 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0010 cost = 6.383853 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0010 cost = 0.373999 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0010 cost = 0.357160 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0010 cost = 0.380083 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0010 cost = 0.353318 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0010 cost = 0.436918 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0010 cost = 0.697205 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0010 cost = 0.001818 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 0.001795 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0010 cost = 0.001774 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0010 cost = 0.001756 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0010 cost = 0.001740 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0010 cost = 0.001725 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0010 cost = 0.001712 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0010 cost = 0.001700 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0010 cost = 0.001689 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0010 cost = 0.001679 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 0.001670 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0010 cost = 0.001662 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0010 cost = 0.001655 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0010 cost = 0.001648 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0010 cost = 0.001642 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0010 cost = 0.001637 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0010 cost = 0.001631 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0010 cost = 0.001627 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0010 cost = 0.001623 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0010 cost = 0.001619 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 0.001615 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0010 cost = 0.001611 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0010 cost = 0.001608 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0010 cost = 0.001605 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0010 cost = 0.001602 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 0.001600 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0010 cost = 0.001597 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0010 cost = 0.001595 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0010 cost = 0.001593 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0010 cost = 0.001591 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0010 cost = 0.001589 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0010 cost = 0.001587 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0010 cost = 0.001585 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0010 cost = 0.001583 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0010 cost = 0.001582 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0010 cost = 0.001580 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0010 cost = 0.001579 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0010 cost = 0.001577 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0010 cost = 0.001575 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 0.001574 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0010 cost = 0.001572 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0010 cost = 0.001571 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0010 cost = 0.001570 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0010 cost = 0.001569 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0010 cost = 0.001567 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0010 cost = 0.001566 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0010 cost = 0.001565 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0010 cost = 0.001563 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0010 cost = 0.001562 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0010 cost = 0.001561 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0010 cost = 0.001560 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0010 cost = 0.001559 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 0.001557 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0010 cost = 0.001556 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0010 cost = 0.001555 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 0.001554 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0010 cost = 0.001553 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0010 cost = 0.001551 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0010 cost = 0.001550 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0010 cost = 0.001549 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0010 cost = 0.001548 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0010 cost = 0.001547 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0010 cost = 0.001546 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0010 cost = 0.001545 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 0.001544 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0010 cost = 0.001543 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0010 cost = 0.001541 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0010 cost = 0.001540 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0010 cost = 0.001539 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0010 cost = 0.001538 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 0.001537 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0010 cost = 0.001536 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0010 cost = 0.001535 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 0.001534 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0010 cost = 0.001533 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 0.001532 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0010 cost = 0.001531 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0010 cost = 0.001530 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0010 cost = 0.001529 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0010 cost = 0.001527 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0010 cost = 0.001526 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0010 cost = 0.001525 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0010 cost = 0.001524 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0010 cost = 0.001523 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0010 cost = 0.001522 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0010 cost = 0.001521 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0010 cost = 0.001520 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0010 cost = 0.001519 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0010 cost = 0.001518 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0010 cost = 0.001517 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0010 cost = 0.001516 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0010 cost = 0.001515 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0010 cost = 0.001514 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0010 cost = 0.001513 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 0.001512 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0010 cost = 0.001511 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0010 cost = 0.001510 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0010 cost = 0.001508 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0010 cost = 0.001508 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0010 cost = 0.001507 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0010 cost = 0.001505 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0010 cost = 0.001504 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0010 cost = 0.001503 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0010 cost = 0.001502 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0010 cost = 0.001501 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 0.001500 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0010 cost = 0.001499 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0010 cost = 0.001498 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0010 cost = 0.001497 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0010 cost = 0.001496 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0010 cost = 0.001495 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0010 cost = 0.001494 output size:  <built-in method size of Tensor object at 0x7f61d86f58f0>
# Epoch: 0010 cost = 0.001493 output size:  <built-in method size of Tensor object at 0x7f61d86fdbf0>
# Epoch: 0010 cost = 0.001492 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0010 cost = 0.001491 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0010 cost = 0.001490 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0010 cost = 0.001489 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0010 cost = 0.001488 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0010 cost = 0.001487 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Training Iteration 0 of epoch 10 complete. Loss: 7.567060947418213; Time taken (s): 0.0399928092956543
# Training Iteration 0 of epoch 11 complete. Loss: 7.164471626281738; Time taken (s): 0.034880638122558594
# Training Iteration 0 of epoch 12 complete. Loss: 6.755947113037109; Time taken (s): 0.037607431411743164
# Training Iteration 0 of epoch 13 complete. Loss: 6.345696449279785; Time taken (s): 0.03392744064331055
# Epoch: 0015 cost = 5.938529 output size:  <built-in method size of Tensor object at 0x7f61d86fde30>
# Training Iteration 0 of epoch 14 complete. Loss: 5.938529014587402; Time taken (s): 0.04062652587890625
# Epoch: 0015 cost = 6.170901 output size:  <built-in method size of Tensor object at 0x7f61d86fdef0>
# Epoch: 0015 cost = 5.629382 output size:  <built-in method size of Tensor object at 0x7f61d86fde30>
# Epoch: 0015 cost = 5.724028 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0015 cost = 6.256527 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0015 cost = 5.667954 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0015 cost = 6.044937 output size:  <built-in method size of Tensor object at 0x7f61d86fde30>
# Epoch: 0015 cost = 5.223464 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0015 cost = 4.846731 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0015 cost = 4.945380 output size:  <built-in method size of Tensor object at 0x7f61d86fdf50>
# Epoch: 0015 cost = 4.857730 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0015 cost = 4.558827 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0015 cost = 0.085938 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0015 cost = 0.088434 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0015 cost = 0.083554 output size:  <built-in method size of Tensor object at 0x7f61d86fdef0>
# Epoch: 0015 cost = 0.077262 output size:  <built-in method size of Tensor object at 0x7f61d86fde30>
# Epoch: 0015 cost = 0.128863 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0015 cost = 0.189775 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0015 cost = 0.001139 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0015 cost = 0.001135 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0015 cost = 0.001131 output size:  <built-in method size of Tensor object at 0x7f61d86fdf50>
# Epoch: 0015 cost = 0.001127 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0015 cost = 0.001123 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0015 cost = 0.001120 output size:  <built-in method size of Tensor object at 0x7f61d86fdef0>
# Epoch: 0015 cost = 0.001117 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0015 cost = 0.001115 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0015 cost = 0.001112 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0015 cost = 0.001110 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0015 cost = 0.001108 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0015 cost = 0.001106 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0015 cost = 0.001104 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0015 cost = 0.001102 output size:  <built-in method size of Tensor object at 0x7f61d86fdd70>
# Epoch: 0015 cost = 0.001100 output size:  <built-in method size of Tensor object at 0x7f61d86f54d0>
# Epoch: 0015 cost = 0.001099 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0015 cost = 0.001097 output size:  <built-in method size of Tensor object at 0x7f61d86fde30>
# Epoch: 0015 cost = 0.001096 output size:  <built-in method size of Tensor object at 0x7f61d86f54d0>
# Epoch: 0015 cost = 0.001095 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0015 cost = 0.001093 output size:  <built-in method size of Tensor object at 0x7f61d86f5710>
# Epoch: 0015 cost = 0.001092 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0015 cost = 0.001091 output size:  <built-in method size of Tensor object at 0x7f61d86f5a10>
# Epoch: 0015 cost = 0.001090 output size:  <built-in method size of Tensor object at 0x7f61d86fdfb0>
# Epoch: 0015 cost = 0.001089 output size:  <built-in method size of Tensor object at 0x7f61d86fdef0>
# Epoch: 0015 cost = 0.001088 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0015 cost = 0.001087 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0015 cost = 0.001086 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0015 cost = 0.001085 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0015 cost = 0.001084 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0015 cost = 0.001083 output size:  <built-in method size of Tensor object at 0x7f61d86fde30>
# Epoch: 0015 cost = 0.001082 output size:  <built-in method size of Tensor object at 0x7f61d86f5a10>
# Epoch: 0015 cost = 0.001081 output size:  <built-in method size of Tensor object at 0x7f61d86fdd70>
# Epoch: 0015 cost = 0.001080 output size:  <built-in method size of Tensor object at 0x7f61d86f5710>
# Epoch: 0015 cost = 0.001080 output size:  <built-in method size of Tensor object at 0x7f61d86fdf50>
# Epoch: 0015 cost = 0.001079 output size:  <built-in method size of Tensor object at 0x7f61d86f54d0>
# Epoch: 0015 cost = 0.001078 output size:  <built-in method size of Tensor object at 0x7f61d86fdfb0>
# Epoch: 0015 cost = 0.001077 output size:  <built-in method size of Tensor object at 0x7f61d86fdd70>
# Epoch: 0015 cost = 0.001076 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0015 cost = 0.001076 output size:  <built-in method size of Tensor object at 0x7f61d86f5a10>
# Epoch: 0015 cost = 0.001075 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0015 cost = 0.001074 output size:  <built-in method size of Tensor object at 0x7f61d86f5710>
# Epoch: 0015 cost = 0.001073 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0015 cost = 0.001073 output size:  <built-in method size of Tensor object at 0x7f61d86fde30>
# Epoch: 0015 cost = 0.001072 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0015 cost = 0.001071 output size:  <built-in method size of Tensor object at 0x7f61d86f54d0>
# Epoch: 0015 cost = 0.001071 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0015 cost = 0.001070 output size:  <built-in method size of Tensor object at 0x7f61d86f5a10>
# Epoch: 0015 cost = 0.001069 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0015 cost = 0.001068 output size:  <built-in method size of Tensor object at 0x7f61d86f5710>
# Epoch: 0015 cost = 0.001067 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0015 cost = 0.001067 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0015 cost = 0.001066 output size:  <built-in method size of Tensor object at 0x7f61d86f5710>
# Epoch: 0015 cost = 0.001066 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0015 cost = 0.001065 output size:  <built-in method size of Tensor object at 0x7f61d86f5a10>
# Epoch: 0015 cost = 0.001065 output size:  <built-in method size of Tensor object at 0x7f61d86fdd70>
# Epoch: 0015 cost = 0.001063 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0015 cost = 0.001063 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0015 cost = 0.001062 output size:  <built-in method size of Tensor object at 0x7f61d86fdef0>
# Epoch: 0015 cost = 0.001061 output size:  <built-in method size of Tensor object at 0x7f61d86fde30>
# Epoch: 0015 cost = 0.001061 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0015 cost = 0.001060 output size:  <built-in method size of Tensor object at 0x7f61d86f5a10>
# Epoch: 0015 cost = 0.001060 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0015 cost = 0.001059 output size:  <built-in method size of Tensor object at 0x7f61d86f5710>
# Epoch: 0015 cost = 0.001058 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0015 cost = 0.001057 output size:  <built-in method size of Tensor object at 0x7f61d86f54d0>
# Epoch: 0015 cost = 0.001057 output size:  <built-in method size of Tensor object at 0x7f61d86fdd70>
# Epoch: 0015 cost = 0.001056 output size:  <built-in method size of Tensor object at 0x7f61d86fdfb0>
# Epoch: 0015 cost = 0.001055 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0015 cost = 0.001055 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0015 cost = 0.001054 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0015 cost = 0.001053 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0015 cost = 0.001053 output size:  <built-in method size of Tensor object at 0x7f61d86fdd70>
# Epoch: 0015 cost = 0.001052 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0015 cost = 0.001051 output size:  <built-in method size of Tensor object at 0x7f61d86fdfb0>
# Epoch: 0015 cost = 0.001051 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0015 cost = 0.001050 output size:  <built-in method size of Tensor object at 0x7f61d86f5a10>
# Epoch: 0015 cost = 0.001049 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0015 cost = 0.001049 output size:  <built-in method size of Tensor object at 0x7f61d86f5710>
# Epoch: 0015 cost = 0.001048 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0015 cost = 0.001047 output size:  <built-in method size of Tensor object at 0x7f61d86f54d0>
# Epoch: 0015 cost = 0.001047 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0015 cost = 0.001046 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0015 cost = 0.001045 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0015 cost = 0.001045 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0015 cost = 0.001044 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0015 cost = 0.001044 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0015 cost = 0.001043 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0015 cost = 0.001042 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0015 cost = 0.001041 output size:  <built-in method size of Tensor object at 0x7f61d86fde30>
# Epoch: 0015 cost = 0.001041 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0015 cost = 0.001040 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0015 cost = 0.001040 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0015 cost = 0.001039 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0015 cost = 0.001038 output size:  <built-in method size of Tensor object at 0x7f61d86fdfb0>
# Epoch: 0015 cost = 0.001037 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0015 cost = 0.001037 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0015 cost = 0.001036 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0015 cost = 0.001036 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0015 cost = 0.001035 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0015 cost = 0.001034 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0015 cost = 0.001034 output size:  <built-in method size of Tensor object at 0x7f61d86fdf50>
# Epoch: 0015 cost = 0.001033 output size:  <built-in method size of Tensor object at 0x7f61d86fdef0>
# Epoch: 0015 cost = 0.001032 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0015 cost = 0.001032 output size:  <built-in method size of Tensor object at 0x7f61d86fdfb0>
# Epoch: 0015 cost = 0.001031 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0015 cost = 0.001030 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0015 cost = 0.001030 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0015 cost = 0.001029 output size:  <built-in method size of Tensor object at 0x7f61d86fdf50>
# Epoch: 0015 cost = 0.001028 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0015 cost = 0.001028 output size:  <built-in method size of Tensor object at 0x7f61d86fde30>
# Epoch: 0015 cost = 0.001027 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0015 cost = 0.001026 output size:  <built-in method size of Tensor object at 0x7f61d86fd7d0>
# Epoch: 0015 cost = 0.001026 output size:  <built-in method size of Tensor object at 0x7f61d86fdef0>
# Epoch: 0015 cost = 0.001025 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0015 cost = 0.001024 output size:  <built-in method size of Tensor object at 0x7f61d86fdf50>
# Epoch: 0015 cost = 0.001024 output size:  <built-in method size of Tensor object at 0x7f61d86fdd70>
# Epoch: 0015 cost = 0.001023 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0015 cost = 0.001022 output size:  <built-in method size of Tensor object at 0x7f61d86fdf50>
# Epoch: 0015 cost = 0.001022 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Training Iteration 0 of epoch 15 complete. Loss: 5.538352966308594; Time taken (s): 0.03781771659851074
# Training Iteration 0 of epoch 16 complete. Loss: 5.147292613983154; Time taken (s): 0.03566694259643555
# Training Iteration 0 of epoch 17 complete. Loss: 4.766186714172363; Time taken (s): 0.03438520431518555
# Training Iteration 0 of epoch 18 complete. Loss: 4.395750999450684; Time taken (s): 0.03578376770019531
# Epoch: 0020 cost = 4.037417 output size:  <built-in method size of Tensor object at 0x7f61d86da050>
# Training Iteration 0 of epoch 19 complete. Loss: 4.037417411804199; Time taken (s): 0.04000282287597656
# Epoch: 0020 cost = 4.247783 output size:  <built-in method size of Tensor object at 0x7f61d86fdfb0>
# Epoch: 0020 cost = 3.638341 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0020 cost = 3.768269 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# Epoch: 0020 cost = 4.286632 output size:  <built-in method size of Tensor object at 0x7f61d86da0b0>
# Epoch: 0020 cost = 3.666678 output size:  <built-in method size of Tensor object at 0x7f61d86fd890>
# Epoch: 0020 cost = 4.100751 output size:  <built-in method size of Tensor object at 0x7f61d86fdfb0>
# Epoch: 0020 cost = 3.319460 output size:  <built-in method size of Tensor object at 0x7f61d86da0b0>
# Epoch: 0020 cost = 3.036246 output size:  <built-in method size of Tensor object at 0x7f61d86fdb90>
# Epoch: 0020 cost = 3.197816 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0020 cost = 3.112099 output size:  <built-in method size of Tensor object at 0x7f61d86da0b0>
# Epoch: 0020 cost = 3.086117 output size:  <built-in method size of Tensor object at 0x7f61d86fdad0>
# Epoch: 0020 cost = 0.038817 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0020 cost = 0.042027 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0020 cost = 0.038017 output size:  <built-in method size of Tensor object at 0x7f61d86da050>
# Epoch: 0020 cost = 0.033666 output size:  <built-in method size of Tensor object at 0x7f61d86fd830>
# Epoch: 0020 cost = 0.058158 output size:  <built-in method size of Tensor object at 0x7f61d86da170>
# Epoch: 0020 cost = 0.077836 output size:  <built-in method size of Tensor object at 0x7f61d86fdd70>
# Epoch: 0020 cost = 0.000950 output size:  <built-in method size of Tensor object at 0x7f61d86fd6b0>
# Epoch: 0020 cost = 0.000947 output size:  <built-in method size of Tensor object at 0x7f61d86fdef0>
# Epoch: 0020 cost = 0.000944 output size:  <built-in method size of Tensor object at 0x7f61d86da0b0>
# Epoch: 0020 cost = 0.000942 output size:  <built-in method size of Tensor object at 0x7f61d86da170>
# Epoch: 0020 cost = 0.000940 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0020 cost = 0.000937 output size:  <built-in method size of Tensor object at 0x7f61d86da0b0>
# Epoch: 0020 cost = 0.000936 output size:  <built-in method size of Tensor object at 0x7f61d86da170>
# Epoch: 0020 cost = 0.000934 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0020 cost = 0.000932 output size:  <built-in method size of Tensor object at 0x7f61d86fd650>
# Epoch: 0020 cost = 0.000930 output size:  <built-in method size of Tensor object at 0x7f61d86da170>
# Epoch: 0020 cost = 0.000929 output size:  <built-in method size of Tensor object at 0x7f61d86fdf50>
# Epoch: 0020 cost = 0.000927 output size:  <built-in method size of Tensor object at 0x7f61d86da050>
# Epoch: 0020 cost = 0.000926 output size:  <built-in method size of Tensor object at 0x7f61d86fdd10>
# Epoch: 0020 cost = 0.000925 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0020 cost = 0.000924 output size:  <built-in method size of Tensor object at 0x7f61d86fdd70>
# Epoch: 0020 cost = 0.000923 output size:  <built-in method size of Tensor object at 0x7f61d86da0b0>
# Epoch: 0020 cost = 0.000921 output size:  <built-in method size of Tensor object at 0x7f61d86fdef0>
# Epoch: 0020 cost = 0.000920 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0020 cost = 0.000919 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0020 cost = 0.000918 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0020 cost = 0.000917 output size:  <built-in method size of Tensor object at 0x7f61d86da170>
# Epoch: 0020 cost = 0.000916 output size:  <built-in method size of Tensor object at 0x7f61d86da050>
# Epoch: 0020 cost = 0.000915 output size:  <built-in method size of Tensor object at 0x7f61d86fd710>
# Epoch: 0020 cost = 0.000914 output size:  <built-in method size of Tensor object at 0x7f61d86da170>
# Epoch: 0020 cost = 0.000914 output size:  <built-in method size of Tensor object at 0x7f61d86fddd0>
# Epoch: 0020 cost = 0.000913 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0020 cost = 0.000912 output size:  <built-in method size of Tensor object at 0x7f61d86fdcb0>
# Epoch: 0020 cost = 0.000911 output size:  <built-in method size of Tensor object at 0x7f61d86da0b0>
# Epoch: 0020 cost = 0.000910 output size:  <built-in method size of Tensor object at 0x7f61d86fdf50>
# Epoch: 0020 cost = 0.000910 output size:  <built-in method size of Tensor object at 0x7f61d86fdc50>
# ...
# Epoch: 0045 cost = 0.000095 output size:  <built-in method size of Tensor object at 0x7f61d86da770>
# Epoch: 0045 cost = 0.000095 output size:  <built-in method size of Tensor object at 0x7f61d86da650>
# Epoch: 0045 cost = 0.000095 output size:  <built-in method size of Tensor object at 0x7f61d86daa10>
# Epoch: 0045 cost = 0.000094 output size:  <built-in method size of Tensor object at 0x7f61d86da3b0>
# Epoch: 0045 cost = 0.000094 output size:  <built-in method size of Tensor object at 0x7f61d86dabf0>
# Epoch: 0045 cost = 0.000094 output size:  <built-in method size of Tensor object at 0x7f61d86da9b0>
# Epoch: 0045 cost = 0.000094 output size:  <built-in method size of Tensor object at 0x7f61d86da650>
# Epoch: 0045 cost = 0.000094 output size:  <built-in method size of Tensor object at 0x7f61d86dabf0>
# Epoch: 0045 cost = 0.000094 output size:  <built-in method size of Tensor object at 0x7f61d86da6b0>
# Epoch: 0045 cost = 0.000094 output size:  <built-in method size of Tensor object at 0x7f61d86da650>
# Epoch: 0045 cost = 0.000094 output size:  <built-in method size of Tensor object at 0x7f61d86dabf0>
# Epoch: 0045 cost = 0.000094 output size:  <built-in method size of Tensor object at 0x7f61d86da170>
# Epoch: 0045 cost = 0.000094 output size:  <built-in method size of Tensor object at 0x7f61d86daa70>
# Epoch: 0045 cost = 0.000094 output size:  <built-in method size of Tensor object at 0x7f61d86da710>
# Epoch: 0045 cost = 0.000094 output size:  <built-in method size of Tensor object at 0x7f61d86da170>
# Epoch: 0045 cost = 0.000094 output size:  <built-in method size of Tensor object at 0x7f61d86da770>
# Epoch: 0045 cost = 0.000094 output size:  <built-in method size of Tensor object at 0x7f61d86dabf0>
# Training Iteration 0 of epoch 45 complete. Loss: 0.3838239014148712; Time taken (s): 0.04049324989318848
# Training Iteration 0 of epoch 46 complete. Loss: 0.3554500341415405; Time taken (s): 0.03667807579040527
# Training Iteration 0 of epoch 47 complete. Loss: 0.3295575976371765; Time taken (s): 0.03420233726501465
# Training Iteration 0 of epoch 48 complete. Loss: 0.3058808743953705; Time taken (s): 0.03640437126159668
# Epoch: 0050 cost = 0.284187 output size:  <built-in method size of Tensor object at 0x7f61d86dac50>
# Training Iteration 0 of epoch 49 complete. Loss: 0.28418686985969543; Time taken (s): 0.03870558738708496
# Epoch: 0050 cost = 0.368382 output size:  <built-in method size of Tensor object at 0x7f61d86da470>
# Epoch: 0050 cost = 0.287201 output size:  <built-in method size of Tensor object at 0x7f61d86da3b0>
# Epoch: 0050 cost = 0.306743 output size:  <built-in method size of Tensor object at 0x7f61d86da8f0>
# Epoch: 0050 cost = 0.302032 output size:  <built-in method size of Tensor object at 0x7f61d86da470>
# Epoch: 0050 cost = 0.336592 output size:  <built-in method size of Tensor object at 0x7f61d86da710>
# Epoch: 0050 cost = 0.308534 output size:  <built-in method size of Tensor object at 0x7f61d86dac50>
# Epoch: 0050 cost = 0.228658 output size:  <built-in method size of Tensor object at 0x7f61d86da950>
# Epoch: 0050 cost = 0.320239 output size:  <built-in method size of Tensor object at 0x7f61d86dab90>
# Epoch: 0050 cost = 0.273164 output size:  <built-in method size of Tensor object at 0x7f61d86da5f0>
# Epoch: 0050 cost = 0.419174 output size:  <built-in method size of Tensor object at 0x7f61d86daad0>
# Epoch: 0050 cost = 0.423237 output size:  <built-in method size of Tensor object at 0x7f61d86dab90>
# Epoch: 0050 cost = 0.006725 output size:  <built-in method size of Tensor object at 0x7f61d86da110>
# Epoch: 0050 cost = 0.006545 output size:  <built-in method size of Tensor object at 0x7f61d86da710>
# Epoch: 0050 cost = 0.005256 output size:  <built-in method size of Tensor object at 0x7f61d86da470>
# Epoch: 0050 cost = 0.008755 output size:  <built-in method size of Tensor object at 0x7f61d86dad70>
# Epoch: 0050 cost = 0.006483 output size:  <built-in method size of Tensor object at 0x7f61d86da710>
# Epoch: 0050 cost = 0.009296 output size:  <built-in method size of Tensor object at 0x7f61d86da8f0>
# Epoch: 0050 cost = 0.000060 output size:  <built-in method size of Tensor object at 0x7f61d86da110>
# Epoch: 0050 cost = 0.000059 output size:  <built-in method size of Tensor object at 0x7f61d86da3b0>
# Epoch: 0050 cost = 0.000059 output size:  <built-in method size of Tensor object at 0x7f61d86dabf0>
# Epoch: 0050 cost = 0.000058 output size:  <built-in method size of Tensor object at 0x7f61d86dac50>
# Epoch: 0050 cost = 0.000058 output size:  <built-in method size of Tensor object at 0x7f61d86da3b0>
# Epoch: 0050 cost = 0.000058 output size:  <built-in method size of Tensor object at 0x7f61d86dabf0>
# Epoch: 0050 cost = 0.000057 output size:  <built-in method size of Tensor object at 0x7f61d86da950>
# Epoch: 0050 cost = 0.000057 output size:  <built-in method size of Tensor object at 0x7f61d86dad70>
# Epoch: 0050 cost = 0.000057 output size:  <built-in method size of Tensor object at 0x7f61d86dab90>
# Epoch: 0050 cost = 0.000056 output size:  <built-in method size of Tensor object at 0x7f61d86da950>
# Epoch: 0050 cost = 0.000056 output size:  <built-in method size of Tensor object at 0x7f61d86da5f0>
# Epoch: 0050 cost = 0.000056 output size:  <built-in method size of Tensor object at 0x7f61d86dab90>
# Epoch: 0050 cost = 0.000056 output size:  <built-in method size of Tensor object at 0x7f61d86dabf0>
# Epoch: 0050 cost = 0.000056 output size:  <built-in method size of Tensor object at 0x7f61d86da3b0>
# Epoch: 0050 cost = 0.000055 output size:  <built-in method size of Tensor object at 0x7f61d86dab30>
# Epoch: 0050 cost = 0.000055 output size:  <built-in method size of Tensor object at 0x7f61d86da710>
# Epoch: 0050 cost = 0.000055 output size:  <built-in method size of Tensor object at 0x7f61d86da3b0>
# Epoch: 0050 cost = 0.000055 output size:  <built-in method size of Tensor object at 0x7f61d86dab30>
# Epoch: 0050 cost = 0.000055 output size:  <built-in method size of Tensor object at 0x7f61d86daad0>
# Epoch: 0050 cost = 0.000055 output size:  <built-in method size of Tensor object at 0x7f61d86da290>
# Epoch: 0050 cost = 0.000055 output size:  <built-in method size of Tensor object at 0x7f61d86dab30>
# Epoch: 0050 cost = 0.000055 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da710>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da290>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da470>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86daad0>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86dabf0>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da770>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da950>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86dabf0>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86dab90>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da470>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da710>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86dac50>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da470>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da770>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86dabf0>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da950>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da8f0>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86daad0>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86daa10>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da8f0>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da470>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da8f0>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da710>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da470>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86dae90>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86dae30>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86dae90>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86dae30>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da470>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da5f0>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86dac50>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da710>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da5f0>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86daad0>
# Epoch: 0050 cost = 0.000054 output size:  <built-in method size of Tensor object at 0x7f61d86da950>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dac50>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86daad0>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da950>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dac50>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da650>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da830>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dab30>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da5f0>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da830>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86daad0>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dac50>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da950>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da470>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dab30>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da950>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da470>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dac50>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da950>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da5f0>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dabf0>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da110>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da950>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da770>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86daad0>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dab90>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da770>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dae30>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dab90>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dab30>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da110>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da710>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dab30>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da830>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dab90>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da830>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dab30>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da3b0>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da830>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dab30>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da650>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dabf0>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da110>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da650>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da110>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da650>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da830>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da5f0>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da710>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dad10>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da5f0>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86daad0>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dae30>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da8f0>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86da770>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86dae30>
# Epoch: 0050 cost = 0.000053 output size:  <built-in method size of Tensor object at 0x7f61d86daad0>

# %%
best_model = NNLM()
best_model.load_state_dict(torch.load(best_model_path))
best_model.cuda(gpu)

cos = nn.CosineSimilarity(dim=0)

lm_similarities = {}
# word pairs to calculate similarity
words = {('women','wife'),('king','man'),('london','paris'),('male','husband')}

# ----------- Calculate LM similarities using cosine similarity ----------
for word_pairs in words:
    w1 = word_pairs[0]
    w2 = word_pairs[1]
    words_tensor = torch.LongTensor([word_to_index.get(w1,word_to_index['<UNK>']),word_to_index.get(w2,word_to_index['<UNK>'])])
    
    words_tensor = words_tensor.cuda(gpu)
    # get word embeddings from the best model
    words_embeds = best_model.embeddings(words_tensor)
    # calculate cosine similarity between word vectors
    sim = cos(words_embeds[0],words_embeds[1])
    lm_similarities[word_pairs] = sim.item()

print(lm_similarities)
# Out:
# {('king', 'man'): 0.02427978441119194, ('london', 'paris'): -0.16264724731445312, ('male', 'husband'): -0.36997461318969727, ('women', 'wife'): -0.404706746339798}

# %%
best_model.embeddings(torch.LongTensor([word_to_index.get('london')]).cuda(gpu)) # Test the embeddings here
# Out:
# tensor([[ 0.7845,  2.5309, -0.3585, -0.0052,  1.3512, -1.9531, -0.6556, -1.2768,
#           1.3718, -0.4796]], device='cuda:0', grad_fn=<EmbeddingBackward0>)
