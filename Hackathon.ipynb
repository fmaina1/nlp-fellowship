# %% [markdown]
# <a href="https://colab.research.google.com/github/fmaina1/nlp-fellowship/blob/main/Hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Web Scrapping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#Fetch the content from the front page
content = requests.get('https://mfa.go.ke/').content

# %%
#Preview of the Content
content
# Out:
# b'<!doctype html>\n<html lang="en-US" class="no-js">\n<head> \n<meta charset="UTF-8" />  \n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n \n<title>FOREIGN &amp; DIASPORA AFFAIRS | KENYA &#8211; REPUBLIC OF KENYA</title>\n<meta name=\'robots\' content=\'max-image-preview:large\' />\n<script type="text/javascript">/*<![CDATA[ */ var html = document.getElementsByTagName("html")[0]; html.className = html.className.replace("no-js", "js"); window.onerror=function(e,f){var body = document.getElementsByTagName("body")[0]; body.className = body.className.replace("rt-loading", ""); var e_file = document.createElement("a");e_file.href = f;console.log( e );console.log( e_file.pathname );}/* ]]>*/</script>\n<link rel=\'dns-prefetch\' href=\'//maxcdn.bootstrapcdn.com\' />\n<link rel=\'dns-prefetch\' href=\'//cdn.linearicons.com\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="FOREIGN &amp; DIASPORA AFFAIRS | KENYA &raquo; Feed" href="https://mfa.go.ke/feed/" />\n<link rel="alternate" type="application/rss+xml" title="FOREIGN &amp; DIASPORA AFFAIRS | KENYA &raquo; Comments Feed" href="https://mfa.go.ke/comments/feed/" />\n<script type="text/javascript">\nwindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/14.0.0\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/14.0.0\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/mfa.go.ke\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=6.0.2"}};\n/*! This file is auto-generated */\n!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode,e=(p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0),i.toDataURL());return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([129777,127995,8205,129778,127999],[129777,127995,8203,129778,127999])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(e=t.source||{}).concatemoji?c(e.concatemoji):e.wpemoji&&e.twemoji&&(c(e.twemoji),c(e.wpemoji)))}(window,document,window._wpemojiSettings);\n</script>\n<style type="text/css">\nimg.wp-smiley,\nimg.emoji {\n\tdisplay: inline !important;\n\tborder: none !important;\n\tbox-shadow: none !important;\n\theight: 1em !important;\n\twidth: 1em !important;\n\tmargin: 0 0.07em !important;\n\tvertical-align: -0.1em !important;\n\tbackground: none !important;\n\tpadding: 0 !important;\n}\n</style>\n\t<link rel=\'stylesheet\' id=\'wp-block-library-css\'  href=\'https://mfa.go.ke/wp-includes/css/dist/block-library/style.min.css?ver=6.0.2\' type=\ ...

# %%
#Initiating the BS4 parser
page = BeautifulSoup(content, 'html.parser')

# %%
#Get all the links in the website
links = page.find_all('a')

# %%
links
# Out:
# [<a href="https://mfa.go.ke" title="FOREIGN &amp; DIASPORA AFFAIRS | KENYA"><img alt="FOREIGN &amp; DIASPORA AFFAIRS | KENYA" class="main_logo" height="150" src="https://mfa.go.ke/wp-content/uploads/2022/12/LOGO-AMENDED-FINAL-1.png" srcset="https://mfa.go.ke/wp-content/uploads/2022/12/LOGO-AMENDED-FINAL-1.png 1.3x" width="398"/><img alt="FOREIGN &amp; DIASPORA AFFAIRS | KENYA" class="sticky_logo" src="https://mfa.go.ke/wp-content/uploads/2022/12/LOGO-AMENDED-FINAL-1.png" srcset="https://mfa.go.ke/wp-content/uploads/2022/12/LOGO-AMENDED-FINAL-1.png 1.3x"/></a>,
#  <a href="https://mfa.go.ke/">HOME</a>,
#  <a href="#">KENYA IN BRIEF</a>,
#  <a href="https://mfa.go.ke/country-profile/">Country Profile</a>,
#  <a href="https://mfa.go.ke/invest-in-kenya/">Invest in Kenya</a>,
#  <a href="https://mfa.go.ke/tourism/">Tourism</a>,
#  <a href="#">ABOUT MFDA</a>,
#  <a href="#">Executive Summary</a>,
#  <a href="https://mfa.go.ke/history/">History</a>,
#  <a href="https://mfa.go.ke/role/">Mandate</a>,
#  <a href="#">Our Structure</a>,
#  <a href="https://mfa.go.ke/leadership/">Leadership</a>,
#  <a href="https://mfa.go.ke/orgstructure/">Organization Structure</a>,
#  <a href="https://mfa.go.ke/former-ministers/">Former Ministers</a>,
#  <a href="https://mfa.go.ke/ps/">Former Principal/Permanent Secretaries</a>,
#  <a href="#">Service Charter</a>,
#  <a href="https://mfa.go.ke/wp-content/uploads/2022/01/SC-Kiswahili.pdf">Sevice Charter -Swahili</a>,
#  <a href="https://mfa.go.ke/wp-content/uploads/2022/01/SC-English.pdf">Service Charter-English</a>,
#  <a href="#">Foreign Service Academy</a>,
#  <a href="#">Treaties</a>,
#  <a href="#">Downloads</a>,
#  <a href="https://mfa.go.ke/downloads/">MFA Documents</a>,
#  <a href="#">FOREIGN POLICY</a>,
#  <a href="https://mfa.go.ke/diplomatic-missions/">Diplomatic Missions</a>,
#  <a href="#">Kenya’s Foreign Policy</a>,
#  <a href="https://mfa.go.ke/historyfp/">Introduction</a>,
#  <a href="https://mfa.go.ke/wp-content/uploads/2022/03/Kenya_Foreign_Policy.pdf">Foreign Policy 2014</a>,
#  <a href="https://mfa.go.ke/candidatures-2/">Kenya Candidatures</a>,
#  <a href="#">OPPORTUNITIES</a>,
#  <a href="https://mfa.go.ke/international-jobs/">International Jobs</a>,
#  <a href="https://mfa.go.ke/tenders/">Tenders</a>,
#  <a href="#">PUBLIC DIPLOMACY</a>,
#  <a href="https://mfa.go.ke/news-2/">MFDA News</a>,
#  <a href="https://mfa.go.ke/pressreleases/">Press Releases</a>,
#  <a href="https://mfa.go.ke/speeches-statements/">Speeches &amp; Statements</a>,
#  <a href="https://mfa.go.ke/publication/">Publications</a>,
#  <a href="https://mfa.go.ke/contact-us/">CONTACT US</a>,
#  <a href="#" target="_self" title=""></a>,
#  <a data-vc-container=".vc_tta" data-vc-tabs="" href="#citizens"><i class="vc_tta-icon entypo-icon entypo-icon-users"></i><span class="vc_tta-title-text">KENYAN CITIZENS</span></a>,
#  <a data-vc-container=".vc_tta" data-vc-tabs="" href="#diaspora"><i class="vc_tta-icon typcn typcn-group"></i><span class="vc_tta-title-text">KENYAN DIASPORA</span></a>,
#  <a data-vc-container=".vc_tta" data-vc-tabs="" href="#MDAS"><span class="vc_tta-title-text">MINISTRIES, DEPARTMENTS &amp; STATE AGENCIES</span></a>,
#  <a data-vc-container=".vc_tta" data-vc-tabs="" href="#diplomatic-corps"><i class="vc_tta-icon entypo-icon entypo-icon-globe"></i><span class="vc_tta-title-text">DIPLOMATIC CORPS</span></a>,
#  <a data-vc-container=".vc_tta" data-vc-tabs="" href="#info-foreigners"><i class="vc_tta-icon fas fa-user-check"></i><span class="vc_tta-title-text">FOREIGNERS</span></a>,
#  <a data-vc-accordion="" data-vc-container=".vc_tta-container" href="#citizens"><i class="vc_tta-icon entypo-icon entypo-icon-users"></i><span class="vc_tta-title-text">KENYAN CITIZENS</span></a>,
#  <a href="http:mfa.go.ke/authentication/" target="_self" title=""><h3 class="rt_heading primary-color heading-font style-1"><span class="icon-doc-1 heading_icon"></span>Document Authentication</h3></a>,
#  <a href="http:mfa.go.ke/advice-to-prospective-migrant-workers/" target="_self" title=""><h3 class="rt_heading primary-color heading-font style-1"><span class="icon-info-circled heading_icon"></span>Advisories</h3></a>,
#  <a href="http:mfa.go.ke/consularservices-missions/" target="_self" title=""><h3 class="rt_heading primary-color heading-font style-1"><span class="icon-pencil heading_icon"></span>Consular Services</h3></a>,
#  <a href="http:mfa.go.ke/international-jobs/" target="_self" title=""><h3 class="rt_heading primary-color heading-font style-1"><span class="icon-certificate heading_icon"></span>International Jobs</h3></a>,
#  <a data-vc-accordion="" data-vc-container=".vc_tta-container" href="#diaspora"><i class="vc_tta-icon typcn typcn-group"></i><span class="vc_tta-title-text">KENYAN DIASPORA</span></a>,
#  <a href="http:mfa.go.ke/index.php/consularservices-missions/" target="_self" title=""><h3 class="rt_heading primary-color style-1"><span class="icon-pencil heading_icon"></span>Consular Services</h3></a>,
#  <a href="http:mfa.go.ke/diaspora-registration/" target="_self" title=""><h3 class="rt_heading primary-color style-1"><span class="icon-laptop heading_icon"></span>Register with us</h3></a>,
#  <a href="http:mfa.go.ke/advice-to-prospective-migrant-workers/" target="_self" title=""><h3 class="rt_heading primary-color style-1"><span class="icon-info-circled heading_icon"></span>Advisory Services</h3></a>,
#  <a href="http:mfa.go.ke/index.php/info-diaspora/" target="_self" title=""><h3 class="rt_heading primary-color style-1"><span class="icon-help-circled heading_icon"></span>Assistance Abroad</h3></a>,
#  <a data-vc-accordion="" data-vc-container=".vc_tta-container" href="#MDAS"><span class="vc_tta-title-text">MINISTRIES, DEPARTMENTS &amp; STATE AGENCIES</span></a>,
#  <a href="http:mfa.go.ke/interface-coordination/" target="_self" title=""><h3 class="rt_heading primary-color style-1"><span class="icon-cog-alt heading_icon"></span>Interface &amp; Coordination</h3></a>,
#  <a href="http:mfa.go.ke/facilitation/" target="_self" title=""><h3 class="rt_heading primary-color style-1"><span class="icon-users heading_icon"></span>Facilitation</h3></a>,
#  <a href="http:mfa.go.ke/advisory/" target="_self" title=""><h3 class="rt_heading primary-color style-1"><span class="icon-info-circled heading_icon"></span>Advisory</h3></a>,
#  <a href="http:mfa.go.ke/treaties/" target="_self" title=""><h3 class="rt_heading primary-color style-1"><span class="icon-note-1 heading_icon"></span>International Treaties</h3></a>,
#  <a href="http:mfa.go.ke/training/" target="_self" title=""><h3 class="rt_heading primary-color style-1"><span class="icon-graduation-cap-1 heading_icon"></span>Training</h3></a>,
#  <a data-vc-accordion="" data-vc-container=".vc_tta-container" href="#diplomatic-corps"><i class="vc_tta-icon entypo-icon entypo-icon-globe"></i><span class="vc_tta-title-text">DIPLOMATIC CORPS</span></a>,
#  <a href="https://ipmis.mfa.go.ke/index.html" target="_blank" title=""><h3 class="rt_heading primary-color style-1"><span class="icon-link heading_icon"></span>E-Protocol</h3></a>,
#  <a href="https://mfa.go.ke/facilitation-coordination/" target="_blank" title=""><h3 class="rt_heading primary-color style-1"><span class="icon-users heading_icon"></span>Facilitation &amp; Coordination</h3></a>,
#  <a data-vc-accordion="" data-vc-container=".vc_tta-container" href="#info-foreigners"><i class="vc_tta-icon fas fa-user-check"></i><span class="vc_tta-title-text">FOREIGNERS</span></a>,
#  <a href="https://kcaa.or.ke/covid-19" target="_blank" title=""><h3 class="rt_heading primary-color style-4"><span class="icon-info heading_icon"></span>Covid-19 Entry Advisory</h3></a>,
#  <a href="https://evisa.go.ke/evisa.html" target="_blank" title=""><h3 class="rt_heading primary-color style-1"><span class="icon-edit-alt heading_icon"></span>Visa Application</h3></a>,
#  <a href="http:mfa.go.ke/invest-in-kenya/" target="_self" title=""><h3 class="rt_heading primary-color style-1"><span class="icon-money heading_icon"></span>Investment</h3></a>,
#  <a href="http:mfa.go.ke/tourism/" target="_self" title=""><h3 class="rt_heading primary-color style-1"><span class="icon-flight heading_icon"></span>Tourism</h3></a>,
#  <a class="vc_pagination-trigger" data-vc-container=".vc_tta" data-vc-tabs="" href="#citizens"></a>,
#  <a class="vc_pagination-trigger" data-vc-container=".vc_tta" data-vc-tabs="" href="#diaspora"></a>,
#  <a class="vc_pagination-trigger" data-vc-container=".vc_tta" data-vc-tabs="" href="#MDAS"></a>,
#  <a class="vc_pagination-trigger" data-vc-container=".vc_tta" data-vc-tabs="" href="#diplomatic-corps"></a>,
#  <a class="vc_pagination-trigger" data-vc-container=".vc_tta" data-vc-tabs="" href="#info-foreigners"></a>,
#  <a data-vc-container=".vc_tta" data-vc-tabs="" href="#mfa-news"><span class="vc_tta-title-text">MFA NEWS</span></a>,
#  <a data-vc-container=".vc_tta" data-vc-tabs="" href="#press-release"><span class="vc_tta-title-text">PRESS RELEASES AND STATEMENTS</span></a>,
#  <a data-vc-container=".vc_tta" data-vc-tabs="" href="#notice"><span class="vc_tta-title-text">ANNOUNCEMENTS AND NOTICES</span></a>,
#  <a data-vc-accordion="" data-vc-container=".vc_tta-container" href="#mfa-news"><span class="vc_tta-title-text">MFA NEWS</span></a>,
#  <a class="title" href="https://mfa.go.ke/business-deals-scholarships-and-trade-agreements-goodies-from-kenya-algeria-meeting/" rel="bookmark" title="BUSINESS DEALS, SCHOLARSHIPS AND TRADE AGREEMENTS GOODIES FROM KENYA-ALGERIA MEETING">BUSINESS DEALS, SCHOLARSHIPS AND TRADE AGREEMENTS GOODIES FROM KENYA-ALGERIA MEETING</a>,
#  <a class="title" href="https://mfa.go.ke/cs-mutua-holds-diplomatic-briefing-with-eu-envoys/" rel="bookmark" title="CS MUTUA HOLDS DIPLOMATIC BRIEFING WITH EU ENVOYS">CS MUTUA HOLDS DIPLOMATIC BRIEFING WITH EU ENVOYS</a>,
#  <a class="title" href="https://mfa.go.ke/kenya-joins-member-states-at-the-48th-ordinary-session-of-the-igad-council-of-ministers/" rel="bookmark" title="KENYA JOINS MEMBER STATES AT THE 48TH ORDINARY SESSION OF THE IGAD COUNCIL OF MINISTERS">KENYA JOINS MEMBER STATES AT THE 48TH ORDINARY SESSION OF THE IGAD COUNCIL OF MINISTERS</a>,
#  <a class="title" href="https://mfa.go.ke/kenya-south-korea-pledge-to-work-together/" rel="bookmark" title="KENYA, SOUTH KOREA PLEDGE TO WORK TOGETHER">KENYA, SOUTH KOREA PLEDGE TO WORK TOGETHER</a>,
#  <a class="title" href="https://mfa.go.ke/cs-mutua-pledges-to-work-closely-with-the-diplomatic-corps-in-kenya/" rel="bookmark" title="CS MUTUA PLEDGES TO WORK CLOSELY WITH THE DIPLOMATIC CORPS IN KENYA">CS MUTUA PLEDGES TO WORK CLOSELY WITH THE DIPLOMATIC CORPS IN KENYA</a>,
#  <a class="title" href="https://mfa.go.ke/kenya-welcomes-the-black-sea-grain-initiative-to-address-the-global-food-crisis-cs-mutua-says/" rel="bookmark" title="KENYA WELCOMES THE BLACK SEA GRAIN INITIATIVE TO ADDRESS THE GLOBAL FOOD CRISIS, CS MUTUA SAYS">KENYA WELCOMES THE BLACK SEA GRAIN INITIATIVE TO ADDRESS THE GLOBAL FOOD CRISIS, CS MUTUA SAYS</a>,
#  <a class="title" href="https://mfa.go.ke/cs-mutua-official-visit-to-the-kingdom-of-saudi-arabia/" rel="bookmark" title="CS MUTUA OFFICIAL VISIT TO THE KINGDOM OF SAUDI ARABIA">CS MUTUA OFFICIAL VISIT TO THE KINGDOM OF SAUDI ARABIA</a>,
#  <a class="title" href="https://mfa.go.ke/cs-mutua-holds-fruitful-discussion-with-us-ambassador-qatar-ambassador-and-dg-unon/" rel="bookmark" title="CS MUTUA HOLDS FRUITFUL DISCUSSION WITH US AMBASSADOR, QATAR AMBASSADOR AND DG UNON">CS MUTUA HOLDS FRUITFUL DISCUSSION WITH US AMBASSADOR, QATAR AMBASSADOR AND DG UNON</a>,
#  <a class="title" href="https://mfa.go.ke/finding-solutions-for-kenyan-diaspora-workers/" rel="bookmark" title="FINDING SOLUTIONS FOR KENYAN DIASPORA WORKERS">FINDING SOLUTIONS FOR KENYAN DIASPORA WORKERS</a>,
#  <a data-vc-accordion="" data-vc-container=".vc_tta-container" href="#press-release"><span class="vc_tta-title-text">PRESS RELEASES AND STATEMENTS</span></a>,
#  <a href="https://mfa.go.ke/wp-content/uploads/2022/05/Press-Release.pdf" rel="noopener" target="_blank">Press Release Kenya -Greece</a>,
#  <a href="https://mfa.go.ke/wp-content/uploads/2022/03/FINAL-PRESS-STATEMENT-ON-OFFICIAL-VISIT-TO-INDONESIA-and-MOUS.pdf">Press Statement on Official Visit to Indonesia</a>,
#  <a href="https://mfa.go.ke/wp-content/uploads/2022/03/PRESS-RELEASE-ON-CS-OMAN-VISIT.pdf">Press Release on CS Oman Visit</a>,
#  <a href="http:mfa.go.ke/wp-content/uploads/2021/11/PRESS-RELEASE-ON-THE-CABINET-SECRETARYS-VISIT-TO-ETHIOPIA.pdf">Press-Release-On-The-Cabinet-Secretarys-Visit-To-Ethiopia</a>,
#  <a href="https://mfa.go.ke/storage/2021/12/INTERNATIONAL-JOBS-Press-.pdf">Press Release – International Jobs</a>,
#  <a href="http:mfa.go.ke/wp-content/uploads/2021/11/PRESS-RELEASE-Cabinet-Secretary-Official-Visit-to-Sudan.pdf">Press-Release-Cabinet-Secretary-Official-Visit-To-Sudan</a>,
#  <a href="http:mfa.go.ke/wp-content/uploads/2021/11/KENYA-SWEDEN-PRESS-STATEMENT-25TH-MAY-2021-.pdf">Kenya-Sweden-Press-Statement-25th-May-2021-</a>,
#  <a href="http:mfa.go.ke/wp-content/uploads/2021/11/KENYA-REINFORCES-THE-SILENCING-OF-THE-GUNS-IN-AFRICA-THROUGH-THE-AMISOM-TCCs-CONSULTATIONS.pdf">Kenya-Reinforces-The-Silencing-of-The-Guns-In-Africa-Through-The-Amisom-Tccs-Consultations</a>,
#  <a href="http:mfa.go.ke/wp-content/uploads/2021/11/Press-Release-Official-Visit.pdf">Press-Release-Official-Visit Of Cabinet Secretary To Tanzania</a>,
#  <a href="http:mfa.go.ke/wp-content/uploads/2021/11/Press-Release-Official-Visit-by-Japan-Foreign-Minister.pdf">Press-Release-Official-Visit-By-Japan-Foreign-Minister</a>,
#  <a href="http:mfa.go.ke/wp-content/uploads/2021/11/Press-release-visit-by-Hon-Dominic-Raab.pdf">Press-Release-visit-by-Hon-Dominic-Raab</a>,
#  <a data-vc-accordion="" data-vc-container=".vc_tta-container" href="#notice"><span class="vc_tta-title-text">ANNOUNCEMENTS AND NOTICES</span></a>,
#  <a href="https://mfa.go.ke/mazingira/" rel="noopener" target="_blank">DETAILS ON THE  AMANI AND MAZINGIRA AWARD 2022</a>,
#  <a href="https://www.kcaa.or.ke/sites/default/files/covid-19/documents/EXEMPT_FROM_QUARANTINE-28.12.2021.pdf" rel="noopener" target="_blank"><img alt="" class="alignnone wp-image-5161" height="176" loading="lazy" sizes="(max-width: 312px) 100vw, 312px" src="https://mfa.go.ke/wp-content/uploads/2022/03/IMG-20220324-WA0000-300x169.jpg" srcset="https://mfa.go.ke/wp-content/uploads/2022/03/IMG-20220324-WA0000-300x169.jpg 300w, https://mfa.go.ke/wp-content/uploads/2022/03/IMG-20220324-WA0000-1024x576.jpg 1024w, https://mfa.go.ke/wp-content/uploads/2022/03/IMG-20220324-WA0000-768x432.jpg 768w, https://mfa.go.ke/wp-content/uploads/2022/03/IMG-20220324-WA0000-1536x864.jpg 1536w, https://mfa.go.ke/wp-content/uploads/2022/03/IMG-20220324-WA0000.jpg 1600w" width="312"/></a>,
#  <a href="https://mfa.go.ke/wp-content/uploads/2021/11/Sustainable_Blue_Economy_Conf_Book.pdf" rel="noopener" target="_blank"><strong>E- BOOK ON SUSTAINABLE BLUE ECONOMY</strong></a>,
#  <a href="https://mfa.go.ke/wp-content/uploads/2021/11/Sustainable_Blue_Economy_Conf_Book.pdf" rel="noopener" target="_blank"><img alt="" class="wp-image-4586 alignnone" height="190" loading="lazy" sizes="(max-width: 314px) 100vw, 314px" src="http:mfa.go.ke/wp-content/uploads/2021/11/Book-Icon-1-1024x617-1-300x181.png" srcset="https://mfa.go.ke/wp-content/uploads/2021/11/Book-Icon-1-1024x617-1-300x181.png 300w, https://mfa.go.ke/wp-content/uploads/2021/11/Book-Icon-1-1024x617-1-768x463.png 768w, https://mfa.go.ke/wp-content/uploads/2021/11/Book-Icon-1-1024x617-1.png 1024w" width="314"/></a>,
#  <a href="https://www.kcaa.or.ke/sites/default/files/covid-19/documents/EXEMPT_FROM_QUARANTINE-28.12.2021.pdf" rel="noopener" target="_blank"><strong>REQUIREMENTS FOR PASSENGERS ARRIVING INTO KENYA</strong></a>,
#  <a href="https://www.kcaa.or.ke/sites/default/files/covid-19/documents/EXEMPT_FROM_QUARANTINE-28.12.2021.pdf" rel="noopener" target="_blank"><img alt="" class="wp-image-4976 alignleft" height="167" loading="lazy" sizes="(max-width: 316px) 100vw, 316px" src="https://mfa.go.ke/storage/2022/01/kcaa-covid-potocol-300x159.jpeg" srcset="https://mfa.go.ke/wp-content/uploads/2022/01/kcaa-covid-potocol-300x159.jpeg 300w, https://mfa.go.ke/wp-content/uploads/2022/01/kcaa-covid-potocol-1024x544.jpeg 1024w, https://mfa.go.ke/wp-content/uploads/2022/01/kcaa-covid-potocol-768x408.jpeg 768w, https://mfa.go.ke/wp-content/uploads/2022/01/kcaa-covid-potocol-1536x816.jpeg 1536w, https://mfa.go.ke/wp-content/uploads/2022/01/kcaa-covid-potocol.jpeg 2048w" width="316"/></a>,
#  <a href="https://twitter.com/ForeignOfficeKE/status/1603569044082270213" target="_blank">
#          December 16, 2022    </a>,
#  <a class="aptf-tweet-name" href="http://twitter.com/ForeignOfficeKE" target="_blank">
#              ForeignAffairsKenya            <span class="aptf-tweet-username">@ForeignOfficeKE</span>
#  </a>,
#  <a href="https://twitter.com/ForeignOfficeKE">ForeignOfficeKE</a>,
#  <a href="https://twitter.com/SecBlinken" rel="nofollow noopener" target="_blank"><img class="aptf-user-img" src="https://pbs.twimg.com/profile_images/1363277550928158722/LzlIxuhQ_normal.jpg"/></a>,
#  <a href="http://www.twitter.com/SecBlinken" target="_blank">@SecBlinken</a>,
#  <a href="http://www.twitter.com/StateHouseKenya" target="_blank">@StateHouseKenya</a>,
#  <a href="https://t.co/yafuL0T3ND" target="_blank">https://t.co/yafuL0T3ND</a>,
#  <a class="aptf-tweet-reply aptf-tweet-action-reply" href="https://twitter.com/intent/tweet?in_reply_to=1603569044082270213" target="_blank"><i class="fa fa-reply"></i></a>,
#  <a class="aptf-tweet-retweet aptf-tweet-action-retweet" href="https://twitter.com/intent/retweet?tweet_id=1603569044082270213" target="_blank"><i class="fa fa-retweet"></i><span class="aptf-count">87</span></a>,
#  <a class="aptf-tweet-fav aptf-tweet-action-favourite" href="https://twitter.com/intent/favorite?tweet_id=1603569044082270213" target="_blank"><i class="fa fa-heart"></i><span class="aptf-count"></span></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkDQWHQWIBAEiz-.jpg"><img src="https://pbs.twimg.com/media/FkDQWHQWIBAEiz-.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkDQXrTXgAEVN-7.jpg"><img src="https://pbs.twimg.com/media/FkDQXrTXgAEVN-7.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkDQvImXkAAJVhU.jpg"><img src="https://pbs.twimg.com/media/FkDQvImXkAAJVhU.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a href="https://twitter.com/ForeignOfficeKE/status/1603419983148875776" target="_blank">
#          December 15, 2022    </a>,
#  <a class="aptf-tweet-name" href="http://twitter.com/ForeignOfficeKE" target="_blank">
#              ForeignAffairsKenya            <span class="aptf-tweet-username">@ForeignOfficeKE</span>
#  </a>,
#  <a href="http://www.twitter.com/DrAlfredMutua" target="_blank">@DrAlfredMutua</a>,
#  <a href="http://www.twitter.com/WilliamsRuto" target="_blank">@WilliamsRuto</a>,
#  <a href="https://t.co/u4MiPwzbuv" target="_blank">https://t.co/u4MiPwzbuv</a>,
#  <a class="aptf-tweet-reply aptf-tweet-action-reply" href="https://twitter.com/intent/tweet?in_reply_to=1603419983148875776" target="_blank"><i class="fa fa-reply"></i></a>,
#  <a class="aptf-tweet-retweet aptf-tweet-action-retweet" href="https://twitter.com/intent/retweet?tweet_id=1603419983148875776" target="_blank"><i class="fa fa-retweet"></i><span class="aptf-count">9</span></a>,
#  <a class="aptf-tweet-fav aptf-tweet-action-favourite" href="https://twitter.com/intent/favorite?tweet_id=1603419983148875776" target="_blank"><i class="fa fa-heart"></i><span class="aptf-count">21</span></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkB9-KPXkAUWylG.jpg"><img src="https://pbs.twimg.com/media/FkB9-KPXkAUWylG.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkB9-KOWAAQM_6i.jpg"><img src="https://pbs.twimg.com/media/FkB9-KOWAAQM_6i.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkB9-KPWYAE_koR.jpg"><img src="https://pbs.twimg.com/media/FkB9-KPWYAE_koR.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkB9-KOWAAAnl-o.jpg"><img src="https://pbs.twimg.com/media/FkB9-KOWAAAnl-o.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a href="https://twitter.com/ForeignOfficeKE/status/1603418870244671491" target="_blank">
#          December 15, 2022    </a>,
#  <a class="aptf-tweet-name" href="http://twitter.com/ForeignOfficeKE" target="_blank">
#              ForeignAffairsKenya            <span class="aptf-tweet-username">@ForeignOfficeKE</span>
#  </a>,
#  <a href="https://t.co/tCiyqdp2qr" target="_blank">https://t.co/tCiyqdp2qr</a>,
#  <a class="aptf-tweet-reply aptf-tweet-action-reply" href="https://twitter.com/intent/tweet?in_reply_to=1603418870244671491" target="_blank"><i class="fa fa-reply"></i></a>,
#  <a class="aptf-tweet-retweet aptf-tweet-action-retweet" href="https://twitter.com/intent/retweet?tweet_id=1603418870244671491" target="_blank"><i class="fa fa-retweet"></i><span class="aptf-count">4</span></a>,
#  <a class="aptf-tweet-fav aptf-tweet-action-favourite" href="https://twitter.com/intent/favorite?tweet_id=1603418870244671491" target="_blank"><i class="fa fa-heart"></i><span class="aptf-count">15</span></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkB865IagAA6RLt.jpg"><img src="https://pbs.twimg.com/media/FkB865IagAA6RLt.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkB8766acAAF072.jpg"><img src="https://pbs.twimg.com/media/FkB8766acAAF072.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkB88oxaYAAK-4Y.jpg"><img src="https://pbs.twimg.com/media/FkB88oxaYAAK-4Y.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkB89YLaYAAV0z5.jpg"><img src="https://pbs.twimg.com/media/FkB89YLaYAAV0z5.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a href="https://twitter.com/ForeignOfficeKE/status/1603412254468325376" target="_blank">
#          December 15, 2022    </a>,
#  <a class="aptf-tweet-name" href="http://twitter.com/ForeignOfficeKE" target="_blank">
#              ForeignAffairsKenya            <span class="aptf-tweet-username">@ForeignOfficeKE</span>
#  </a>,
#  <a href="https://t.co/aMqBHS1NG0" target="_blank">https://t.co/aMqBHS1NG0</a>,
#  <a class="aptf-tweet-reply aptf-tweet-action-reply" href="https://twitter.com/intent/tweet?in_reply_to=1603412254468325376" target="_blank"><i class="fa fa-reply"></i></a>,
#  <a class="aptf-tweet-retweet aptf-tweet-action-retweet" href="https://twitter.com/intent/retweet?tweet_id=1603412254468325376" target="_blank"><i class="fa fa-retweet"></i><span class="aptf-count">7</span></a>,
#  <a class="aptf-tweet-fav aptf-tweet-action-favourite" href="https://twitter.com/intent/favorite?tweet_id=1603412254468325376" target="_blank"><i class="fa fa-heart"></i><span class="aptf-count">9</span></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkB2630XkAI6Rqy.jpg"><img src="https://pbs.twimg.com/media/FkB2630XkAI6Rqy.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkB263zXEAUR4Nj.jpg"><img src="https://pbs.twimg.com/media/FkB263zXEAUR4Nj.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkB263yWIAE4lBz.jpg"><img src="https://pbs.twimg.com/media/FkB263yWIAE4lBz.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a data-lightbox="@ForeignOfficeKE" href="https://pbs.twimg.com/media/FkB2632WAAMOPAD.jpg"><img src="https://pbs.twimg.com/media/FkB2632WAAMOPAD.jpg:thumb" style="max-width: 100%;"/></a>,
#  <a href="mailto:info@mfa.go.ke">info@mfa.go.ke</a>,
#  <a href="http://www.president.go.ke/" rel="noopener" target="_blank">THE PRESIDENCY</a>,
#  <a href="https://brand.ke/" rel="noopener" target="_blank">BRAND KENYA</a>,
#  <a href="https://www.ecitizen.go.ke/" rel="noopener" target="_blank">E CITIZEN</a>,
#  <a href="http://www.invest.go.ke/" rel="noopener" target="_blank">KENYA INVESTMENT AUTHORITY</a>,
#  <a href="https://mail.govmail.ke/">STAFF MAIL</a>,
#  <a href="https://pms.mfa.go.ke/">PMS</a>,
#  <a href="https://www.ghris.go.ke/">GHRIS</a>,
#  <a aria-label="Accessibility Statement" id="mdp-readabler-statement-btn">Accessibility Statement</a>]

# %%
#Drop the first link because it's not related
del links[0]

# %%
index = -30
link = links[index]['href'] #Get the link
title = links[index].text #Save the description
print('Link:', link, 'Described as:', title)
# Out:
# Link: https://pbs.twimg.com/media/FkB9-KOWAAAnl-o.jpg Described as:

# %%
list_of_links = [] #list()
list_of_titles = []

for item in links: #loop over the list of links
  if str(item['href'])[0:9] == 'index.php':
    lin = 'https://mfa.go.ke/' + item['href']
  else:
    lin = item['href']

  list_of_links.append(lin)
  if len(item.text) > 0:
    list_of_titles.append(item.text)
  else:
    list_of_titles.append(None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-e0503688695e> in <module>
#       3
#       4 for item in links: #loop over the list of links
# ----> 5   if str(item['href'])[0:9] == 'index.php':
#       6     lin = 'https://mfa.go.ke/' + item['href']
#       7   else:
#
# /usr/local/lib/python3.8/dist-packages/bs4/element.py in __getitem__(self, key)
#    1069         """tag[key] returns the value of the 'key' attribute for the tag,
#    1070         and throws an exception if it's not there."""
# -> 1071         return self.attrs[key]
#    1072
#    1073     def __iter__(self):
#
# KeyError: 'href'

# %%
df = pd.DataFrame()
df['title'] = list_of_titles
df['link'] = list_of_links
df['description'] = None

# %%
list_of_links
# Out:
# ['https://mfa.go.ke/',
#  '#',
#  'https://mfa.go.ke/country-profile/',
#  'https://mfa.go.ke/invest-in-kenya/',
#  'https://mfa.go.ke/tourism/',
#  '#',
#  '#',
#  'https://mfa.go.ke/history/',
#  'https://mfa.go.ke/role/',
#  '#',
#  'https://mfa.go.ke/leadership/',
#  'https://mfa.go.ke/orgstructure/',
#  'https://mfa.go.ke/former-ministers/',
#  'https://mfa.go.ke/ps/',
#  '#',
#  'https://mfa.go.ke/wp-content/uploads/2022/01/SC-Kiswahili.pdf',
#  'https://mfa.go.ke/wp-content/uploads/2022/01/SC-English.pdf',
#  '#',
#  '#',
#  '#',
#  'https://mfa.go.ke/downloads/',
#  '#',
#  'https://mfa.go.ke/diplomatic-missions/',
#  '#',
#  'https://mfa.go.ke/historyfp/',
#  'https://mfa.go.ke/wp-content/uploads/2022/03/Kenya_Foreign_Policy.pdf',
#  'https://mfa.go.ke/candidatures-2/',
#  '#',
#  'https://mfa.go.ke/international-jobs/',
#  'https://mfa.go.ke/tenders/',
#  '#',
#  'https://mfa.go.ke/news-2/',
#  'https://mfa.go.ke/pressreleases/',
#  'https://mfa.go.ke/speeches-statements/',
#  'https://mfa.go.ke/publication/',
#  'https://mfa.go.ke/contact-us/',
#  '#',
#  '#citizens',
#  '#diaspora',
#  '#MDAS',
#  '#diplomatic-corps',
#  '#info-foreigners',
#  '#citizens',
#  'http:mfa.go.ke/authentication/',
#  'http:mfa.go.ke/advice-to-prospective-migrant-workers/',
#  'http:mfa.go.ke/consularservices-missions/',
#  'http:mfa.go.ke/international-jobs/',
#  '#diaspora',
#  'http:mfa.go.ke/index.php/consularservices-missions/',
#  'http:mfa.go.ke/diaspora-registration/',
#  'http:mfa.go.ke/advice-to-prospective-migrant-workers/',
#  'http:mfa.go.ke/index.php/info-diaspora/',
#  '#MDAS',
#  'http:mfa.go.ke/interface-coordination/',
#  'http:mfa.go.ke/facilitation/',
#  'http:mfa.go.ke/advisory/',
#  'http:mfa.go.ke/treaties/',
#  'http:mfa.go.ke/training/',
#  '#diplomatic-corps',
#  'https://ipmis.mfa.go.ke/index.html',
#  'https://mfa.go.ke/facilitation-coordination/',
#  '#info-foreigners',
#  'https://kcaa.or.ke/covid-19',
#  'https://evisa.go.ke/evisa.html',
#  'http:mfa.go.ke/invest-in-kenya/',
#  'http:mfa.go.ke/tourism/',
#  '#citizens',
#  '#diaspora',
#  '#MDAS',
#  '#diplomatic-corps',
#  '#info-foreigners',
#  '#mfa-news',
#  '#press-release',
#  '#notice',
#  '#mfa-news',
#  'https://mfa.go.ke/business-deals-scholarships-and-trade-agreements-goodies-from-kenya-algeria-meeting/',
#  'https://mfa.go.ke/cs-mutua-holds-diplomatic-briefing-with-eu-envoys/',
#  'https://mfa.go.ke/kenya-joins-member-states-at-the-48th-ordinary-session-of-the-igad-council-of-ministers/',
#  'https://mfa.go.ke/kenya-south-korea-pledge-to-work-together/',
#  'https://mfa.go.ke/cs-mutua-pledges-to-work-closely-with-the-diplomatic-corps-in-kenya/',
#  'https://mfa.go.ke/kenya-welcomes-the-black-sea-grain-initiative-to-address-the-global-food-crisis-cs-mutua-says/',
#  'https://mfa.go.ke/cs-mutua-official-visit-to-the-kingdom-of-saudi-arabia/',
#  'https://mfa.go.ke/cs-mutua-holds-fruitful-discussion-with-us-ambassador-qatar-ambassador-and-dg-unon/',
#  'https://mfa.go.ke/finding-solutions-for-kenyan-diaspora-workers/',
#  '#press-release',
#  'https://mfa.go.ke/wp-content/uploads/2022/05/Press-Release.pdf',
#  'https://mfa.go.ke/wp-content/uploads/2022/03/FINAL-PRESS-STATEMENT-ON-OFFICIAL-VISIT-TO-INDONESIA-and-MOUS.pdf',
#  'https://mfa.go.ke/wp-content/uploads/2022/03/PRESS-RELEASE-ON-CS-OMAN-VISIT.pdf',
#  'http:mfa.go.ke/wp-content/uploads/2021/11/PRESS-RELEASE-ON-THE-CABINET-SECRETARYS-VISIT-TO-ETHIOPIA.pdf',
#  'https://mfa.go.ke/storage/2021/12/INTERNATIONAL-JOBS-Press-.pdf',
#  'http:mfa.go.ke/wp-content/uploads/2021/11/PRESS-RELEASE-Cabinet-Secretary-Official-Visit-to-Sudan.pdf',
#  'http:mfa.go.ke/wp-content/uploads/2021/11/KENYA-SWEDEN-PRESS-STATEMENT-25TH-MAY-2021-.pdf',
#  'http:mfa.go.ke/wp-content/uploads/2021/11/KENYA-REINFORCES-THE-SILENCING-OF-THE-GUNS-IN-AFRICA-THROUGH-THE-AMISOM-TCCs-CONSULTATIONS.pdf',
#  'http:mfa.go.ke/wp-content/uploads/2021/11/Press-Release-Official-Visit.pdf',
#  'http:mfa.go.ke/wp-content/uploads/2021/11/Press-Release-Official-Visit-by-Japan-Foreign-Minister.pdf',
#  'http:mfa.go.ke/wp-content/uploads/2021/11/Press-release-visit-by-Hon-Dominic-Raab.pdf',
#  '#notice',
#  'https://mfa.go.ke/mazingira/',
#  'https://www.kcaa.or.ke/sites/default/files/covid-19/documents/EXEMPT_FROM_QUARANTINE-28.12.2021.pdf',
#  'https://mfa.go.ke/wp-content/uploads/2021/11/Sustainable_Blue_Economy_Conf_Book.pdf',
#  'https://mfa.go.ke/wp-content/uploads/2021/11/Sustainable_Blue_Economy_Conf_Book.pdf',
#  'https://www.kcaa.or.ke/sites/default/files/covid-19/documents/EXEMPT_FROM_QUARANTINE-28.12.2021.pdf',
#  'https://www.kcaa.or.ke/sites/default/files/covid-19/documents/EXEMPT_FROM_QUARANTINE-28.12.2021.pdf',
#  'https://twitter.com/ForeignOfficeKE/status/1603569044082270213',
#  'http://twitter.com/ForeignOfficeKE',
#  'https://twitter.com/ForeignOfficeKE',
#  'https://twitter.com/SecBlinken',
#  'http://www.twitter.com/SecBlinken',
#  'http://www.twitter.com/StateHouseKenya',
#  'https://t.co/yafuL0T3ND',
#  'https://twitter.com/intent/tweet?in_reply_to=1603569044082270213',
#  'https://twitter.com/intent/retweet?tweet_id=1603569044082270213',
#  'https://twitter.com/intent/favorite?tweet_id=1603569044082270213',
#  'https://pbs.twimg.com/media/FkDQWHQWIBAEiz-.jpg',
#  'https://pbs.twimg.com/media/FkDQXrTXgAEVN-7.jpg',
#  'https://pbs.twimg.com/media/FkDQvImXkAAJVhU.jpg',
#  'https://twitter.com/ForeignOfficeKE/status/1603419983148875776',
#  'http://twitter.com/ForeignOfficeKE',
#  'http://www.twitter.com/DrAlfredMutua',
#  'http://www.twitter.com/WilliamsRuto',
#  'https://t.co/u4MiPwzbuv',
#  'https://twitter.com/intent/tweet?in_reply_to=1603419983148875776',
#  'https://twitter.com/intent/retweet?tweet_id=1603419983148875776',
#  'https://twitter.com/intent/favorite?tweet_id=1603419983148875776',
#  'https://pbs.twimg.com/media/FkB9-KPXkAUWylG.jpg',
#  'https://pbs.twimg.com/media/FkB9-KOWAAQM_6i.jpg',
#  'https://pbs.twimg.com/media/FkB9-KPWYAE_koR.jpg',
#  'https://pbs.twimg.com/media/FkB9-KOWAAAnl-o.jpg',
#  'https://twitter.com/ForeignOfficeKE/status/1603418870244671491',
#  'http://twitter.com/ForeignOfficeKE',
#  'https://t.co/tCiyqdp2qr',
#  'https://twitter.com/intent/tweet?in_reply_to=1603418870244671491',
#  'https://twitter.com/intent/retweet?tweet_id=1603418870244671491',
#  'https://twitter.com/intent/favorite?tweet_id=1603418870244671491',
#  'https://pbs.twimg.com/media/FkB865IagAA6RLt.jpg',
#  'https://pbs.twimg.com/media/FkB8766acAAF072.jpg',
#  'https://pbs.twimg.com/media/FkB88oxaYAAK-4Y.jpg',
#  'https://pbs.twimg.com/media/FkB89YLaYAAV0z5.jpg',
#  'https://twitter.com/ForeignOfficeKE/status/1603412254468325376',
#  'http://twitter.com/ForeignOfficeKE',
#  'https://t.co/aMqBHS1NG0',
#  'https://twitter.com/intent/tweet?in_reply_to=1603412254468325376',
#  'https://twitter.com/intent/retweet?tweet_id=1603412254468325376',
#  'https://twitter.com/intent/favorite?tweet_id=1603412254468325376',
#  'https://pbs.twimg.com/media/FkB2630XkAI6Rqy.jpg',
#  'https://pbs.twimg.com/media/FkB263zXEAUR4Nj.jpg',
#  'https://pbs.twimg.com/media/FkB263yWIAE4lBz.jpg',
#  'https://pbs.twimg.com/media/FkB2632WAAMOPAD.jpg',
#  'mailto:info@mfa.go.ke',
#  'http://www.president.go.ke/',
#  'https://brand.ke/',
#  'https://www.ecitizen.go.ke/',
#  'http://www.invest.go.ke/',
#  'https://mail.govmail.ke/',
#  'https://pms.mfa.go.ke/',
#  'https://www.ghris.go.ke/']

# %%
#Preview the dataframe
df.describe()
# Out:
#                                                     title link description
# count                                                 126  156           0
# unique                                                109  124           0
# top     \r\n            ForeignAffairsKenya           ...    #         NaN
# freq                                                    4   13         NaN

# %%
#Drop all the row with empty title columns
df = df.dropna(subset=['title'])

# %%
df
# Out:
#                           title                                link  \
# 0                          HOME                  https://mfa.go.ke/
# 1                KENYA IN BRIEF                                   #
# 2               Country Profile  https://mfa.go.ke/country-profile/
# 3               Invest in Kenya  https://mfa.go.ke/invest-in-kenya/
# 4                       Tourism          https://mfa.go.ke/tourism/
# ..                          ...                                 ...
# 151                   E CITIZEN         https://www.ecitizen.go.ke/
# 152  KENYA INVESTMENT AUTHORITY            http://www.invest.go.ke/
# 153                  STAFF MAIL            https://mail.govmail.ke/
# 154                         PMS              https://pms.mfa.go.ke/
# 155                       GHRIS            https://www.ghris.go.ke/
#
#     description
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ..          ...
# 151        None
# 152        None
# 153        None
# 154        None
# 155        None
#
# [126 rows x 3 columns]

# %%
#Check whehter the link is full formated link
is_full_link = df.link.str.startswith('http')

#Check whether the link is pdf documents
is_pdf = df.link.str.contains('.pdf')

# %%
df['is_full_link'] = is_full_link #Create a new col
df['is_pdf'] = is_pdf #create a new col

# %%
df
# Out:
#                           title                                link  \
# 0                          HOME                  https://mfa.go.ke/
# 1                KENYA IN BRIEF                                   #
# 2               Country Profile  https://mfa.go.ke/country-profile/
# 3               Invest in Kenya  https://mfa.go.ke/invest-in-kenya/
# 4                       Tourism          https://mfa.go.ke/tourism/
# ..                          ...                                 ...
# 151                   E CITIZEN         https://www.ecitizen.go.ke/
# 152  KENYA INVESTMENT AUTHORITY            http://www.invest.go.ke/
# 153                  STAFF MAIL            https://mail.govmail.ke/
# 154                         PMS              https://pms.mfa.go.ke/
# 155                       GHRIS            https://www.ghris.go.ke/
#
#     description  is_full_link  is_pdf
# 0          None          True   False
# 1          None         False   False
# 2          None          True   False
# 3          None          True   False
# 4          None          True   False
# ..          ...           ...     ...
# 151        None          True   False
# 152        None          True   False
# 153        None          True   False
# 154        None          True   False
# 155        None          True   False
#
# [126 rows x 5 columns]

# %%
df = df[df['is_full_link'] == True ] #Drop all the links
df =  df[df['is_pdf'] == False ]

# %%
df
# Out:
#                           title                                link  \
# 0                          HOME                  https://mfa.go.ke/
# 2               Country Profile  https://mfa.go.ke/country-profile/
# 3               Invest in Kenya  https://mfa.go.ke/invest-in-kenya/
# 4                       Tourism          https://mfa.go.ke/tourism/
# 7                       History          https://mfa.go.ke/history/
# ..                          ...                                 ...
# 151                   E CITIZEN         https://www.ecitizen.go.ke/
# 152  KENYA INVESTMENT AUTHORITY            http://www.invest.go.ke/
# 153                  STAFF MAIL            https://mail.govmail.ke/
# 154                         PMS              https://pms.mfa.go.ke/
# 155                       GHRIS            https://www.ghris.go.ke/
#
#     description  is_full_link  is_pdf
# 0          None          True   False
# 2          None          True   False
# 3          None          True   False
# 4          None          True   False
# 7          None          True   False
# ..          ...           ...     ...
# 151        None          True   False
# 152        None          True   False
# 153        None          True   False
# 154        None          True   False
# 155        None          True   False
#
# [81 rows x 5 columns]

# %%
# import textract as tx

# description = []
# #Get the description of each job

# for index in range(len(df)):
#   try:
#     if df['link'][index].str.endswith('.pdf'):
#       content =  requests.get(df['link'][index]).raw
#       with open(f'test{index}.pdf', 'w+') as file:
#         file.write(content)

#       doc = tx.process(f'test{index}.pdf')

#       df.loc[index]['description'] = doc.text

#     raw_content = requests.get(df['link'][index]).content
#     df.loc[index]['description'] = raw_content.text
#   except :
#     pass

# %%
# description = []
# #Get the description of each job

# for index in range(3):
#   try:
#     raw_content = requests.get(df['link'][index]).content
#     description.append(raw_content.text)
#   except :
#     description.append('')

# df['description'] = description

# %%
df
# Out:
#                           title                                link  \
# 0                          HOME                  https://mfa.go.ke/
# 2               Country Profile  https://mfa.go.ke/country-profile/
# 3               Invest in Kenya  https://mfa.go.ke/invest-in-kenya/
# 4                       Tourism          https://mfa.go.ke/tourism/
# 7                       History          https://mfa.go.ke/history/
# ..                          ...                                 ...
# 151                   E CITIZEN         https://www.ecitizen.go.ke/
# 152  KENYA INVESTMENT AUTHORITY            http://www.invest.go.ke/
# 153                  STAFF MAIL            https://mail.govmail.ke/
# 154                         PMS              https://pms.mfa.go.ke/
# 155                       GHRIS            https://www.ghris.go.ke/
#
#     description  is_full_link  is_pdf
# 0          None          True   False
# 2          None          True   False
# 3          None          True   False
# 4          None          True   False
# 7          None          True   False
# ..          ...           ...     ...
# 151        None          True   False
# 152        None          True   False
# 153        None          True   False
# 154        None          True   False
# 155        None          True   False
#
# [81 rows x 5 columns]

# %%
import re 

def preprocessing(titles : list):
  cleaned_titles = []
  for title in titles:
    title = title.lower()
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    html_pattern = re.compile('<.*?>')
    title = url_pattern.sub(r'', title)
    title = html_pattern.sub(r'', title)
    title = re.sub(r"[^\w\d'\s]+", ' ', title)
    cleaned_titles.append(title)
  return cleaned_titles


df['title'] = preprocessing(df['title'])

# %%
df
# Out:
#                           title                                link  \
# 0                          home                  https://mfa.go.ke/
# 2               country profile  https://mfa.go.ke/country-profile/
# 3               invest in kenya  https://mfa.go.ke/invest-in-kenya/
# 4                       tourism          https://mfa.go.ke/tourism/
# 7                       history          https://mfa.go.ke/history/
# ..                          ...                                 ...
# 151                   e citizen         https://www.ecitizen.go.ke/
# 152  kenya investment authority            http://www.invest.go.ke/
# 153                  staff mail            https://mail.govmail.ke/
# 154                         pms              https://pms.mfa.go.ke/
# 155                       ghris            https://www.ghris.go.ke/
#
#     description  is_full_link  is_pdf
# 0          None          True   False
# 2          None          True   False
# 3          None          True   False
# 4          None          True   False
# 7          None          True   False
# ..          ...           ...     ...
# 151        None          True   False
# 152        None          True   False
# 153        None          True   False
# 154        None          True   False
# 155        None          True   False
#
# [81 rows x 5 columns]

# %% [markdown]
# # Start Building the chatbot

# %% [markdown]
# ## Building the intent file

# %%
question = """Guide me to {}?
Where do you get {}?
What is the link to the {}?
How do you get {}?
Who is in Charge of {}?"""

answers = """Here is the link {}.
You can use this link {} for more information."""

# %%
question.split('\n')
# Out:
# ['Guide me to {}?',
#  'Where do you get {}?',
#  'What is the link to the {}?',
#  'How do you get {}?',
#  'Who is in Charge of {}?']

# %%
df.iloc[10]
# Out:
# title                          mfa documents
# link            https://mfa.go.ke/downloads/
# description                             None
# is_full_link                            True
# is_pdf                                 False
# Name: 20, dtype: object

# %%
intents = []

for index in range(len(df)):
  intent = {}
  tag = df.iloc[index]['title']
  intent['tag'] = tag
  intent['patterns'] = list()
  intent['responses'] = [f'You can use this link {df.iloc[index].link} for more information']
  for i in range(len(question.split('\n'))):
    intent['patterns'].append(question.split('\n')[i].format(intent['tag']))

  intents.append(intent)
  
file = {'intents': intents}

# %%
file
# Out:
# {'intents': [{'tag': 'home',
#    'patterns': ['Guide me to home?',
#     'Where do you get home?',
#     'What is the link to the home?',
#     'How do you get home?',
#     'Who is in Charge of home?'],
#    'responses': ['You can use this link https://mfa.go.ke/ for more information']},
#   {'tag': 'country profile',
#    'patterns': ['Guide me to country profile?',
#     'Where do you get country profile?',
#     'What is the link to the country profile?',
#     'How do you get country profile?',
#     'Who is in Charge of country profile?'],
#    'responses': ['You can use this link https://mfa.go.ke/country-profile/ for more information']},
#   {'tag': 'invest in kenya',
#    'patterns': ['Guide me to invest in kenya?',
#     'Where do you get invest in kenya?',
#     'What is the link to the invest in kenya?',
#     'How do you get invest in kenya?',
#     'Who is in Charge of invest in kenya?'],
#    'responses': ['You can use this link https://mfa.go.ke/invest-in-kenya/ for more information']},
#   {'tag': 'tourism',
#    'patterns': ['Guide me to tourism?',
#     'Where do you get tourism?',
#     'What is the link to the tourism?',
#     'How do you get tourism?',
#     'Who is in Charge of tourism?'],
#    'responses': ['You can use this link https://mfa.go.ke/tourism/ for more information']},
#   {'tag': 'history',
#    'patterns': ['Guide me to history?',
#     'Where do you get history?',
#     'What is the link to the history?',
#     'How do you get history?',
#     'Who is in Charge of history?'],
#    'responses': ['You can use this link https://mfa.go.ke/history/ for more information']},
#   {'tag': 'mandate',
#    'patterns': ['Guide me to mandate?',
#     'Where do you get mandate?',
#     'What is the link to the mandate?',
#     'How do you get mandate?',
#     'Who is in Charge of mandate?'],
#    'responses': ['You can use this link https://mfa.go.ke/role/ for more information']},
#   {'tag': 'leadership',
#    'patterns': ['Guide me to leadership?',
#     'Where do you get leadership?',
#     'What is the link to the leadership?',
#     'How do you get leadership?',
#     'Who is in Charge of leadership?'],
#    'responses': ['You can use this link https://mfa.go.ke/leadership/ for more information']},
#   {'tag': 'organization structure',
#    'patterns': ['Guide me to organization structure?',
#     'Where do you get organization structure?',
#     'What is the link to the organization structure?',
#     'How do you get organization structure?',
#     'Who is in Charge of organization structure?'],
#    'responses': ['You can use this link https://mfa.go.ke/orgstructure/ for more information']},
#   {'tag': 'former ministers',
#    'patterns': ['Guide me to former ministers?',
#     'Where do you get former ministers?',
#     'What is the link to the former ministers?',
#     'How do you get former ministers?',
#     'Who is in Charge of former ministers?'],
#    'responses': ['You can use this link https://mfa.go.ke/former-ministers/ for more information']},
#   {'tag': 'former principal permanent secretaries',
#    'patterns': ['Guide me to former principal permanent secretaries?',
#     'Where do you get former principal permanent secretaries?',
#     'What is the link to the former principal permanent secretaries?',
#     'How do you get former principal permanent secretaries?',
#     'Who is in Charge of former principal permanent secretaries?'],
#    'responses': ['You can use this link https://mfa.go.ke/ps/ for more information']},
#   {'tag': 'mfa documents',
#    'patterns': ['Guide me to mfa documents?',
#     'Where do you get mfa documents?',
#     'What is the link to the mfa documents?',
#     'How do you get mfa documents?',
#     'Who is in Charge of mfa documents?'],
#    'responses': ['You can use this link https://mfa.go.ke/downloads/ for more information']},
#   {'tag': 'diplomatic missions',
#    'patterns': ['Guide me to diplomatic missions?',
#     'Where do you get diplomatic missions?',
#     'What is the link to the diplomatic missions?',
#     'How do you get diplomatic missions?',
#     'Who is in Charge of diplomatic missions?'],
#    'responses': ['You can use this link https://mfa.go.ke/diplomatic-missions/ for more information']},
#   {'tag': 'introduction',
#    'patterns': ['Guide me to introduction?',
#     'Where do you get introduction?',
#     'What is the link to the introduction?',
#     'How do you get introduction?',
#     'Who is in Charge of introduction?'],
#    'responses': ['You can use this link https://mfa.go.ke/historyfp/ for more information']},
#   {'tag': 'kenya candidatures',
#    'patterns': ['Guide me to kenya candidatures?',
#     'Where do you get kenya candidatures?',
#     'What is the link to the kenya candidatures?',
#     'How do you get kenya candidatures?',
#     'Who is in Charge of kenya candidatures?'],
#    'responses': ['You can use this link https://mfa.go.ke/candidatures-2/ for more information']},
#   {'tag': 'international jobs',
#    'patterns': ['Guide me to international jobs?',
#     'Where do you get international jobs?',
#     'What is the link to the international jobs?',
#     'How do you get international jobs?',
#     'Who is in Charge of international jobs?'],
#    'responses': ['You can use this link https://mfa.go.ke/international-jobs/ for more information']},
#   {'tag': 'tenders',
#    'patterns': ['Guide me to tenders?',
#     'Where do you get tenders?',
#     'What is the link to the tenders?',
#     'How do you get tenders?',
#     'Who is in Charge of tenders?'],
#    'responses': ['You can use this link https://mfa.go.ke/tenders/ for more information']},
#   {'tag': 'mfda news',
#    'patterns': ['Guide me to mfda news?',
#     'Where do you get mfda news?',
#     'What is the link to the mfda news?',
#     'How do you get mfda news?',
#     'Who is in Charge of mfda news?'],
#    'responses': ['You can use this link https://mfa.go.ke/news-2/ for more information']},
#   {'tag': 'press releases',
#    'patterns': ['Guide me to press releases?',
#     'Where do you get press releases?',
#     'What is the link to the press releases?',
#     'How do you get press releases?',
#     'Who is in Charge of press releases?'],
#    'responses': ['You can use this link https://mfa.go.ke/pressreleases/ for more information']},
#   {'tag': 'speeches   statements',
#    'patterns': ['Guide me to speeches   statements?',
#     'Where do you get speeches   statements?',
#     'What is the link to the speeches   statements?',
#     'How do you get speeches   statements?',
#     'Who is in Charge of speeches   statements?'],
#    'responses': ['You can use this link https://mfa.go.ke/speeches-statements/ for more information']},
#   {'tag': 'publications',
#    'patterns': ['Guide me to publications?',
#     'Where do you get publications?',
#     'What is the link to the publications?',
#     'How do you get publications?',
#     'Who is in Charge of publications?'],
#    'responses': ['You can use this link https://mfa.go.ke/publication/ for more information']},
#   {'tag': 'contact us',
#    'patterns': ['Guide me to contact us?',
#     'Where do you get contact us?',
#     'What is the link to the contact us?',
#     'How do you get contact us?',
#     'Who is in Charge of contact us?'],
#    'responses': ['You can use this link https://mfa.go.ke/contact-us/ for more information']},
#   {'tag': 'document authentication',
#    'patterns': ['Guide me to document authentication?',
#     'Where do you get document authentication?',
#     'What is the link to the document authentication?',
#     'How do you get document authentication?',
#     'Who is in Charge of document authentication?'],
#    'responses': ['You can use this link http:mfa.go.ke/authentication/ for more information']},
#   {'tag': 'advisories',
#    'patterns': ['Guide me to advisories?',
#     'Where do you get advisories?',
#     'What is the link to the advisories?',
#     'How do you get advisories?',
#     'Who is in Charge of advisories?'],
#    'responses': ['You can use this link http:mfa.go.ke/advice-to-prospective-migrant-workers/ for more information']},
#   {'tag': 'consular services',
#    'patterns': ['Guide me to consular services?',
#     'Where do you get consular services?',
#     'What is the link to the consular services?',
#     'How do you get consular services?',
#     'Who is in Charge of consular services?'],
#    'responses': ['You can use this link http:mfa.go.ke/consularservices-missions/ for more information']},
#   {'tag': 'international jobs',
#    'patterns': ['Guide me to international jobs?',
#     'Where do you get international jobs?',
#     'What is the link to the international jobs?',
#     'How do you get international jobs?',
#     'Who is in Charge of international jobs?'],
#    'responses': ['You can use this link http:mfa.go.ke/international-jobs/ for more information']},
#   {'tag': 'consular services',
#    'patterns': ['Guide me to consular services?',
#     'Where do you get consular services?',
#     'What is the link to the consular services?',
#     'How do you get consular services?',
#     'Who is in Charge of consular services?'],
#    'responses': ['You can use this link http:mfa.go.ke/index.php/consularservices-missions/ for more information']},
#   {'tag': 'register with us',
#    'patterns': ['Guide me to register with us?',
#     'Where do you get register with us?',
#     'What is the link to the register with us?',
#     'How do you get register with us?',
#     'Who is in Charge of register with us?'],
#    'responses': ['You can use this link http:mfa.go.ke/diaspora-registration/ for more information']},
#   {'tag': 'advisory services',
#    'patterns': ['Guide me to advisory services?',
#     'Where do you get advisory services?',
#     'What is the link to the advisory services?',
#     'How do you get advisory services?',
#     'Who is in Charge of advisory services?'],
#    'responses': ['You can use this link http:mfa.go.ke/advice-to-prospective-migrant-workers/ for more information']},
#   {'tag': 'assistance abroad',
#    'patterns': ['Guide me to assistance abroad?',
#     'Where do you get assistance abroad?',
#     'What is the link to the assistance abroad?',
#     'How do you get assistance abroad?',
#     'Who is in Charge of assistance abroad?'],
#    'responses': ['You can use this link http:mfa.go.ke/index.php/info-diaspora/ for more information']},
#   {'tag': 'interface   coordination',
#    'patterns': ['Guide me to interface   coordination?',
#     'Where do you get interface   coordination?',
#     'What is the link to the interface   coordination?',
#     'How do you get interface   coordination?',
#     'Who is in Charge of interface   coordination?'],
#    'responses': ['You can use this link http:mfa.go.ke/interface-coordination/ for more information']},
#   {'tag': 'facilitation',
#    'patterns': ['Guide me to facilitation?',
#     'Where do you get facilitation?',
#     'What is the link to the facilitation?',
#     'How do you get facilitation?',
#     'Who is in Charge of facilitation?'],
#    'responses': ['You can use this link http:mfa.go.ke/facilitation/ for more information']},
#   {'tag': 'advisory',
#    'patterns': ['Guide me to advisory?',
#     'Where do you get advisory?',
#     'What is the link to the advisory?',
#     'How do you get advisory?',
#     'Who is in Charge of advisory?'],
#    'responses': ['You can use this link http:mfa.go.ke/advisory/ for more information']},
#   {'tag': 'international treaties',
#    'patterns': ['Guide me to international treaties?',
#     'Where do you get international treaties?',
#     'What is the link to the international treaties?',
#     'How do you get international treaties?',
#     'Who is in Charge of international treaties?'],
#    'responses': ['You can use this link http:mfa.go.ke/treaties/ for more information']},
#   {'tag': 'training',
#    'patterns': ['Guide me to training?',
#     'Where do you get training?',
#     'What is the link to the training?',
#     'How do you get training?',
#     'Who is in Charge of training?'],
#    'responses': ['You can use this link http:mfa.go.ke/training/ for more information']},
#   {'tag': 'e protocol',
#    'patterns': ['Guide me to e protocol?',
#     'Where do you get e protocol?',
#     'What is the link to the e protocol?',
#     'How do you get e protocol?',
#     'Who is in Charge of e protocol?'],
#    'responses': ['You can use this link https://ipmis.mfa.go.ke/index.html for more information']},
#   {'tag': 'facilitation   coordination',
#    'patterns': ['Guide me to facilitation   coordination?',
#     'Where do you get facilitation   coordination?',
#     'What is the link to the facilitation   coordination?',
#     'How do you get facilitation   coordination?',
#     'Who is in Charge of facilitation   coordination?'],
#    'responses': ['You can use this link https://mfa.go.ke/facilitation-coordination/ for more information']},
#   {'tag': 'covid 19 entry advisory',
#    'patterns': ['Guide me to covid 19 entry advisory?',
#     'Where do you get covid 19 entry advisory?',
#     'What is the link to the covid 19 entry advisory?',
#     'How do you get covid 19 entry advisory?',
#     'Who is in Charge of covid 19 entry advisory?'],
#    'responses': ['You can use this link https://kcaa.or.ke/covid-19 for more information']},
#   {'tag': 'visa application',
#    'patterns': ['Guide me to visa application?',
#     'Where do you get visa application?',
#     'What is the link to the visa application?',
#     'How do you get visa application?',
#     'Who is in Charge of visa application?'],
#    'responses': ['You can use this link https://evisa.go.ke/evisa.html for more information']},
#   {'tag': 'investment',
#    'patterns': ['Guide me to investment?',
#     'Where do you get investment?',
#     'What is the link to the investment?',
#     'How do you get investment?',
#     'Who is in Charge of investment?'],
#    'responses': ['You can use this link http:mfa.go.ke/invest-in-kenya/ for more information']},
#   {'tag': 'tourism',
#    'patterns': ['Guide me to tourism?',
#     'Where do you get tourism?',
#     'What is the link to the tourism?',
#     'How do you get tourism?',
#     'Who is in Charge of tourism?'],
#    'responses': ['You can use this link http:mfa.go.ke/tourism/ for more information']},
#   {'tag': 'business deals  scholarships and trade agreements goodies from kenya algeria meeting',
#    'patterns': ['Guide me to business deals  scholarships and trade agreements goodies from kenya algeria meeting?',
#     'Where do you get business deals  scholarships and trade agreements goodies from kenya algeria meeting?',
#     'What is the link to the business deals  scholarships and trade agreements goodies from kenya algeria meeting?',
#     'How do you get business deals  scholarships and trade agreements goodies from kenya algeria meeting?',
#     'Who is in Charge of business deals  scholarships and trade agreements goodies from kenya algeria meeting?'],
#    'responses': ['You can use this link https://mfa.go.ke/business-deals-scholarships-and-trade-agreements-goodies-from-kenya-algeria-meeting/ for more information']},
#   {'tag': 'cs mutua holds diplomatic briefing with eu envoys',
#    'patterns': ['Guide me to cs mutua holds diplomatic briefing with eu envoys?',
#     'Where do you get cs mutua holds diplomatic briefing with eu envoys?',
#     'What is the link to the cs mutua holds diplomatic briefing with eu envoys?',
#     'How do you get cs mutua holds diplomatic briefing with eu envoys?',
#     'Who is in Charge of cs mutua holds diplomatic briefing with eu envoys?'],
#    'responses': ['You can use this link https://mfa.go.ke/cs-mutua-holds-diplomatic-briefing-with-eu-envoys/ for more information']},
#   {'tag': 'kenya joins member states at the 48th ordinary session of the igad council of ministers',
#    'patterns': ['Guide me to kenya joins member states at the 48th ordinary session of the igad council of ministers?',
#     'Where do you get kenya joins member states at the 48th ordinary session of the igad council of ministers?',
#     'What is the link to the kenya joins member states at the 48th ordinary session of the igad council of ministers?',
#     'How do you get kenya joins member states at the 48th ordinary session of the igad council of ministers?',
#     'Who is in Charge of kenya joins member states at the 48th ordinary session of the igad council of ministers?'],
#    'responses': ['You can use this link https://mfa.go.ke/kenya-joins-member-states-at-the-48th-ordinary-session-of-the-igad-council-of-ministers/ for more information']},
#   {'tag': 'kenya  south korea pledge to work together',
#    'patterns': ['Guide me to kenya  south korea pledge to work together?',
#     'Where do you get kenya  south korea pledge to work together?',
#     'What is the link to the kenya  south korea pledge to work together?',
#     'How do you get kenya  south korea pledge to work together?',
#     'Who is in Charge of kenya  south korea pledge to work together?'],
#    'responses': ['You can use this link https://mfa.go.ke/kenya-south-korea-pledge-to-work-together/ for more information']},
#   {'tag': 'cs mutua pledges to work closely with the diplomatic corps in kenya',
#    'patterns': ['Guide me to cs mutua pledges to work closely with the diplomatic corps in kenya?',
#     'Where do you get cs mutua pledges to work closely with the diplomatic corps in kenya?',
#     'What is the link to the cs mutua pledges to work closely with the diplomatic corps in kenya?',
#     'How do you get cs mutua pledges to work closely with the diplomatic corps in kenya?',
#     'Who is in Charge of cs mutua pledges to work closely with the diplomatic corps in kenya?'],
#    'responses': ['You can use this link https://mfa.go.ke/cs-mutua-pledges-to-work-closely-with-the-diplomatic-corps-in-kenya/ for more information']},
#   {'tag': 'kenya welcomes the black sea grain initiative to address the global food crisis  cs mutua says',
#    'patterns': ['Guide me to kenya welcomes the black sea grain initiative to address the global food crisis  cs mutua says?',
#     'Where do you get kenya welcomes the black sea grain initiative to address the global food crisis  cs mutua says?',
#     'What is the link to the kenya welcomes the black sea grain initiative to address the global food crisis  cs mutua says?',
#     'How do you get kenya welcomes the black sea grain initiative to address the global food crisis  cs mutua says?',
#     'Who is in Charge of kenya welcomes the black sea grain initiative to address the global food crisis  cs mutua says?'],
#    'responses': ['You can use this link https://mfa.go.ke/kenya-welcomes-the-black-sea-grain-initiative-to-address-the-global-food-crisis-cs-mutua-says/ for more information']},
#   {'tag': 'cs mutua official visit to the kingdom of saudi arabia',
#    'patterns': ['Guide me to cs mutua official visit to the kingdom of saudi arabia?',
#     'Where do you get cs mutua official visit to the kingdom of saudi arabia?',
#     'What is the link to the cs mutua official visit to the kingdom of saudi arabia?',
#     'How do you get cs mutua official visit to the kingdom of saudi arabia?',
#     'Who is in Charge of cs mutua official visit to the kingdom of saudi arabia?'],
#    'responses': ['You can use this link https://mfa.go.ke/cs-mutua-official-visit-to-the-kingdom-of-saudi-arabia/ for more information']},
#   {'tag': 'cs mutua holds fruitful discussion with us ambassador  qatar ambassador and dg unon',
#    'patterns': ['Guide me to cs mutua holds fruitful discussion with us ambassador  qatar ambassador and dg unon?',
#     'Where do you get cs mutua holds fruitful discussion with us ambassador  qatar ambassador and dg unon?',
#     'What is the link to the cs mutua holds fruitful discussion with us ambassador  qatar ambassador and dg unon?',
#     'How do you get cs mutua holds fruitful discussion with us ambassador  qatar ambassador and dg unon?',
#     'Who is in Charge of cs mutua holds fruitful discussion with us ambassador  qatar ambassador and dg unon?'],
#    'responses': ['You can use this link https://mfa.go.ke/cs-mutua-holds-fruitful-discussion-with-us-ambassador-qatar-ambassador-and-dg-unon/ for more information']},
#   {'tag': 'finding solutions for kenyan diaspora workers',
#    'patterns': ['Guide me to finding solutions for kenyan diaspora workers?',
#     'Where do you get finding solutions for kenyan diaspora workers?',
#     'What is the link to the finding solutions for kenyan diaspora workers?',
#     'How do you get finding solutions for kenyan diaspora workers?',
#     'Who is in Charge of finding solutions for kenyan diaspora workers?'],
#    'responses': ['You can use this link https://mfa.go.ke/finding-solutions-for-kenyan-diaspora-workers/ for more information']},
#   {'tag': 'details on the\xa0 amani and mazingira award 2022',
#    'patterns': ['Guide me to details on the\xa0 amani and mazingira award 2022?',
#     'Where do you get details on the\xa0 amani and mazingira award 2022?',
#     'What is the link to the details on the\xa0 amani and mazingira award 2022?',
#     'How do you get details on the\xa0 amani and mazingira award 2022?',
#     'Who is in Charge of details on the\xa0 amani and mazingira award 2022?'],
#    'responses': ['You can use this link https://mfa.go.ke/mazingira/ for more information']},
#   {'tag': '\r\n        december 16  2022    ',
#    'patterns': ['Guide me to \r\n        december 16  2022    ?',
#     'Where do you get \r\n        december 16  2022    ?',
#     'What is the link to the \r\n        december 16  2022    ?',
#     'How do you get \r\n        december 16  2022    ?',
#     'Who is in Charge of \r\n        december 16  2022    ?'],
#    'responses': ['You can use this link https://twitter.com/ForeignOfficeKE/status/1603569044082270213 for more information']},
#   {'tag': '\r\n            foreignaffairskenya             foreignofficeke\n',
#    'patterns': ['Guide me to \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'Where do you get \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'What is the link to the \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'How do you get \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'Who is in Charge of \r\n            foreignaffairskenya             foreignofficeke\n?'],
#    'responses': ['You can use this link http://twitter.com/ForeignOfficeKE for more information']},
#   {'tag': 'foreignofficeke',
#    'patterns': ['Guide me to foreignofficeke?',
#     'Where do you get foreignofficeke?',
#     'What is the link to the foreignofficeke?',
#     'How do you get foreignofficeke?',
#     'Who is in Charge of foreignofficeke?'],
#    'responses': ['You can use this link https://twitter.com/ForeignOfficeKE for more information']},
#   {'tag': ' secblinken',
#    'patterns': ['Guide me to  secblinken?',
#     'Where do you get  secblinken?',
#     'What is the link to the  secblinken?',
#     'How do you get  secblinken?',
#     'Who is in Charge of  secblinken?'],
#    'responses': ['You can use this link http://www.twitter.com/SecBlinken for more information']},
#   {'tag': ' statehousekenya',
#    'patterns': ['Guide me to  statehousekenya?',
#     'Where do you get  statehousekenya?',
#     'What is the link to the  statehousekenya?',
#     'How do you get  statehousekenya?',
#     'Who is in Charge of  statehousekenya?'],
#    'responses': ['You can use this link http://www.twitter.com/StateHouseKenya for more information']},
#   {'tag': '',
#    'patterns': ['Guide me to ?',
#     'Where do you get ?',
#     'What is the link to the ?',
#     'How do you get ?',
#     'Who is in Charge of ?'],
#    'responses': ['You can use this link https://t.co/yafuL0T3ND for more information']},
#   {'tag': '87',
#    'patterns': ['Guide me to 87?',
#     'Where do you get 87?',
#     'What is the link to the 87?',
#     'How do you get 87?',
#     'Who is in Charge of 87?'],
#    'responses': ['You can use this link https://twitter.com/intent/retweet?tweet_id=1603569044082270213 for more information']},
#   {'tag': '\r\n        december 15  2022    ',
#    'patterns': ['Guide me to \r\n        december 15  2022    ?',
#     'Where do you get \r\n        december 15  2022    ?',
#     'What is the link to the \r\n        december 15  2022    ?',
#     'How do you get \r\n        december 15  2022    ?',
#     'Who is in Charge of \r\n        december 15  2022    ?'],
#    'responses': ['You can use this link https://twitter.com/ForeignOfficeKE/status/1603419983148875776 for more information']},
#   {'tag': '\r\n            foreignaffairskenya             foreignofficeke\n',
#    'patterns': ['Guide me to \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'Where do you get \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'What is the link to the \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'How do you get \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'Who is in Charge of \r\n            foreignaffairskenya             foreignofficeke\n?'],
#    'responses': ['You can use this link http://twitter.com/ForeignOfficeKE for more information']},
#   {'tag': ' dralfredmutua',
#    'patterns': ['Guide me to  dralfredmutua?',
#     'Where do you get  dralfredmutua?',
#     'What is the link to the  dralfredmutua?',
#     'How do you get  dralfredmutua?',
#     'Who is in Charge of  dralfredmutua?'],
#    'responses': ['You can use this link http://www.twitter.com/DrAlfredMutua for more information']},
#   {'tag': ' williamsruto',
#    'patterns': ['Guide me to  williamsruto?',
#     'Where do you get  williamsruto?',
#     'What is the link to the  williamsruto?',
#     'How do you get  williamsruto?',
#     'Who is in Charge of  williamsruto?'],
#    'responses': ['You can use this link http://www.twitter.com/WilliamsRuto for more information']},
#   {'tag': '',
#    'patterns': ['Guide me to ?',
#     'Where do you get ?',
#     'What is the link to the ?',
#     'How do you get ?',
#     'Who is in Charge of ?'],
#    'responses': ['You can use this link https://t.co/u4MiPwzbuv for more information']},
#   {'tag': '9',
#    'patterns': ['Guide me to 9?',
#     'Where do you get 9?',
#     'What is the link to the 9?',
#     'How do you get 9?',
#     'Who is in Charge of 9?'],
#    'responses': ['You can use this link https://twitter.com/intent/retweet?tweet_id=1603419983148875776 for more information']},
#   {'tag': '21',
#    'patterns': ['Guide me to 21?',
#     'Where do you get 21?',
#     'What is the link to the 21?',
#     'How do you get 21?',
#     'Who is in Charge of 21?'],
#    'responses': ['You can use this link https://twitter.com/intent/favorite?tweet_id=1603419983148875776 for more information']},
#   {'tag': '\r\n        december 15  2022    ',
#    'patterns': ['Guide me to \r\n        december 15  2022    ?',
#     'Where do you get \r\n        december 15  2022    ?',
#     'What is the link to the \r\n        december 15  2022    ?',
#     'How do you get \r\n        december 15  2022    ?',
#     'Who is in Charge of \r\n        december 15  2022    ?'],
#    'responses': ['You can use this link https://twitter.com/ForeignOfficeKE/status/1603418870244671491 for more information']},
#   {'tag': '\r\n            foreignaffairskenya             foreignofficeke\n',
#    'patterns': ['Guide me to \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'Where do you get \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'What is the link to the \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'How do you get \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'Who is in Charge of \r\n            foreignaffairskenya             foreignofficeke\n?'],
#    'responses': ['You can use this link http://twitter.com/ForeignOfficeKE for more information']},
#   {'tag': '',
#    'patterns': ['Guide me to ?',
#     'Where do you get ?',
#     'What is the link to the ?',
#     'How do you get ?',
#     'Who is in Charge of ?'],
#    'responses': ['You can use this link https://t.co/tCiyqdp2qr for more information']},
#   {'tag': '4',
#    'patterns': ['Guide me to 4?',
#     'Where do you get 4?',
#     'What is the link to the 4?',
#     'How do you get 4?',
#     'Who is in Charge of 4?'],
#    'responses': ['You can use this link https://twitter.com/intent/retweet?tweet_id=1603418870244671491 for more information']},
#   {'tag': '15',
#    'patterns': ['Guide me to 15?',
#     'Where do you get 15?',
#     'What is the link to the 15?',
#     'How do you get 15?',
#     'Who is in Charge of 15?'],
#    'responses': ['You can use this link https://twitter.com/intent/favorite?tweet_id=1603418870244671491 for more information']},
#   {'tag': '\r\n        december 15  2022    ',
#    'patterns': ['Guide me to \r\n        december 15  2022    ?',
#     'Where do you get \r\n        december 15  2022    ?',
#     'What is the link to the \r\n        december 15  2022    ?',
#     'How do you get \r\n        december 15  2022    ?',
#     'Who is in Charge of \r\n        december 15  2022    ?'],
#    'responses': ['You can use this link https://twitter.com/ForeignOfficeKE/status/1603412254468325376 for more information']},
#   {'tag': '\r\n            foreignaffairskenya             foreignofficeke\n',
#    'patterns': ['Guide me to \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'Where do you get \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'What is the link to the \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'How do you get \r\n            foreignaffairskenya             foreignofficeke\n?',
#     'Who is in Charge of \r\n            foreignaffairskenya             foreignofficeke\n?'],
#    'responses': ['You can use this link http://twitter.com/ForeignOfficeKE for more information']},
#   {'tag': '',
#    'patterns': ['Guide me to ?',
#     'Where do you get ?',
#     'What is the link to the ?',
#     'How do you get ?',
#     'Who is in Charge of ?'],
#    'responses': ['You can use this link https://t.co/aMqBHS1NG0 for more information']},
#   {'tag': '7',
#    'patterns': ['Guide me to 7?',
#     'Where do you get 7?',
#     'What is the link to the 7?',
#     'How do you get 7?',
#     'Who is in Charge of 7?'],
#    'responses': ['You can use this link https://twitter.com/intent/retweet?tweet_id=1603412254468325376 for more information']},
#   {'tag': '9',
#    'patterns': ['Guide me to 9?',
#     'Where do you get 9?',
#     'What is the link to the 9?',
#     'How do you get 9?',
#     'Who is in Charge of 9?'],
#    'responses': ['You can use this link https://twitter.com/intent/favorite?tweet_id=1603412254468325376 for more information']},
#   {'tag': 'the presidency',
#    'patterns': ['Guide me to the presidency?',
#     'Where do you get the presidency?',
#     'What is the link to the the presidency?',
#     'How do you get the presidency?',
#     'Who is in Charge of the presidency?'],
#    'responses': ['You can use this link http://www.president.go.ke/ for more information']},
#   {'tag': 'brand kenya',
#    'patterns': ['Guide me to brand kenya?',
#     'Where do you get brand kenya?',
#     'What is the link to the brand kenya?',
#     'How do you get brand kenya?',
#     'Who is in Charge of brand kenya?'],
#    'responses': ['You can use this link https://brand.ke/ for more information']},
#   {'tag': 'e citizen',
#    'patterns': ['Guide me to e citizen?',
#     'Where do you get e citizen?',
#     'What is the link to the e citizen?',
#     'How do you get e citizen?',
#     'Who is in Charge of e citizen?'],
#    'responses': ['You can use this link https://www.ecitizen.go.ke/ for more information']},
#   {'tag': 'kenya investment authority',
#    'patterns': ['Guide me to kenya investment authority?',
#     'Where do you get kenya investment authority?',
#     'What is the link to the kenya investment authority?',
#     'How do you get kenya investment authority?',
#     'Who is in Charge of kenya investment authority?'],
#    'responses': ['You can use this link http://www.invest.go.ke/ for more information']},
#   {'tag': 'staff mail',
#    'patterns': ['Guide me to staff mail?',
#     'Where do you get staff mail?',
#     'What is the link to the staff mail?',
#     'How do you get staff mail?',
#     'Who is in Charge of staff mail?'],
#    'responses': ['You can use this link https://mail.govmail.ke/ for more information']},
#   {'tag': 'pms',
#    'patterns': ['Guide me to pms?',
#     'Where do you get pms?',
#     'What is the link to the pms?',
#     'How do you get pms?',
#     'Who is in Charge of pms?'],
#    'responses': ['You can use this link https://pms.mfa.go.ke/ for more information']},
#   {'tag': 'ghris',
#    'patterns': ['Guide me to ghris?',
#     'Where do you get ghris?',
#     'What is the link to the ghris?',
#     'How do you get ghris?',
#     'Who is in Charge of ghris?'],
#    'responses': ['You can use this link https://www.ghris.go.ke/ for more information']}]}

# %%
# !git clone https://github.com/agent87/pytorch-chatbot.git
# Out:
# Cloning into 'pytorch-chatbot'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 44 (delta 12), reused 8 (delta 8), pack-reused 23
# Unpacking objects: 100% (44/44), done.

# %%
import json

with open('/content/pytorch-chatbot/intents.json', 'w+') as intent_file:
  intent_file.seek(0)
  intent_file.truncate()
  json.dump(file, intent_file)

# %%
# %cd pytorch-chatbot/
# Out:
# /content/pytorch-chatbot

# %%
import nltk 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Train the Chatbot to associate the patterns/questions to an intent

# %%
# !python train.py
# Out:
# 405 patterns
# 69 tags: ['', '\r\n            foreignaffairskenya             foreignofficeke\n', '\r\n        december 15  2022    ', '\r\n        december 16  2022    ', ' dralfredmutua', ' secblinken', ' statehousekenya', ' williamsruto', '15', '21', '4', '7', '87', '9', 'advisories', 'advisory', 'advisory services', 'assistance abroad', 'brand kenya', 'business deals  scholarships and trade agreements goodies from kenya algeria meeting', 'consular services', 'contact us', 'country profile', 'covid 19 entry advisory', 'cs mutua holds diplomatic briefing with eu envoys', 'cs mutua holds fruitful discussion with us ambassador  qatar ambassador and dg unon', 'cs mutua official visit to the kingdom of saudi arabia', 'cs mutua pledges to work closely with the diplomatic corps in kenya', 'details on the\xa0 amani and mazingira award 2022', 'diplomatic missions', 'document authentication', 'e citizen', 'e protocol', 'facilitation', 'facilitation   coordination', 'finding solutions for kenyan diaspora workers', 'foreignofficeke', 'former ministers', 'former principal permanent secretaries', 'ghris', 'history', 'home', 'interface   coordination', 'international jobs', 'international treaties', 'introduction', 'invest in kenya', 'investment', 'kenya  south korea pledge to work together', 'kenya candidatures', 'kenya investment authority', 'kenya joins member states at the 48th ordinary session of the igad council of ministers', 'kenya welcomes the black sea grain initiative to address the global food crisis  cs mutua says', 'leadership', 'mandate', 'mfa documents', 'mfda news', 'organization structure', 'pms', 'press releases', 'publications', 'register with us', 'speeches   statements', 'staff mail', 'tenders', 'the presidency', 'tourism', 'training', 'visa application']
# 157 unique stemmed words: ['15', '16', '19', '2022', '21', '4', '48th', '7', '87', '9', 'abroad', 'address', 'advisori', 'agreement', 'algeria', 'amani', 'ambassador', 'and', 'applic', 'arabia', 'assist', 'at', 'authent', 'author', 'award', 'black', 'brand', 'brief', 'busi', 'candidatur', 'charg', 'citizen', 'close', 'consular', 'contact', 'coordin', 'corp', 'council', 'countri', 'covid', 'crisi', 'cs', 'deal', 'decemb', 'detail', 'dg', 'diaspora', 'diplomat', 'discuss', 'do', 'document', 'dralfredmutua', 'e', 'entri', 'envoy', 'eu', 'facilit', 'find', 'food', 'for', 'foreignaffairskenya', 'foreignofficek', 'former', 'from', 'fruit', 'get', 'ghri', 'global', 'goodi', 'grain', 'guid', 'histori', 'hold', 'home', 'how', 'igad', 'in', 'initi', 'interfac', 'intern', 'introduct', 'invest', 'is', 'job', 'join', 'kenya', 'kenyan', 'kingdom', 'korea', 'leadership', 'link', 'mail', 'mandat', 'mazingira', 'me', 'meet', 'member', 'mfa', 'mfda', 'minist', 'mission', 'mutua', 'news', 'of', 'offici', 'on', 'ordinari', 'organ', 'perman', 'pledg', 'pm', 'presid', 'press', 'princip', 'profil', 'protocol', 'public', 'qatar', 'regist', 'releas', 'saudi', 'say', 'scholarship', 'sea', 'secblinken', 'secretari', 'servic', 'session', 'solut', 'south', 'speech', 'staff', 'state', 'statehousekenya', 'statement', 'structur', 'tender', 'the', 'to', 'togeth', 'tourism', 'trade', 'train', 'treati', 'unon', 'us', 'visa', 'visit', 'welcom', 'what', 'where', 'who', 'williamsruto', 'with', 'work', 'worker', 'you']
# 157 69
# Epoch [100/1000], Loss: 0.1800
# Epoch [200/1000], Loss: 0.0002
# Epoch [300/1000], Loss: 0.0001
# Epoch [400/1000], Loss: 0.0000
# Epoch [500/1000], Loss: 0.0000
# Epoch [600/1000], Loss: 0.0000
# Epoch [700/1000], Loss: 0.0000
# Epoch [800/1000], Loss: 0.1457
# Epoch [900/1000], Loss: 0.0000
# Epoch [1000/1000], Loss: 0.0000
# final loss: 0.0000
# training complete. file saved to data.pth

# %%
# !python chat.py
# Out:
# Let's chat! (type 'quit' to exit)
# You: Where do you get kenya investment authority
# Sam: You can use this link http://www.invest.go.ke/ for more information
# You: quit

# %%
import random
import json

import torch

from model import NeuralNet
from nltk_utils import bag_of_words, tokenize

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

with open('intents.json', 'r') as json_data:
    intents = json.load(json_data)

FILE = "data.pth"
data = torch.load(FILE)

input_size = data["input_size"]
hidden_size = data["hidden_size"]
output_size = data["output_size"]
all_words = data['all_words']
tags = data['tags']
model_state = data["model_state"]

model = NeuralNet(input_size, hidden_size, output_size).to(device)
model.load_state_dict(model_state)
model.eval()

bot_name = "Patrice"
print("Let's chat! (type 'quit' to exit)")

def query(question : str):
  # sentence = "do you use credit cards?"
  sentence = question

  sentence = tokenize(sentence)
  X = bag_of_words(sentence, all_words)
  X = X.reshape(1, X.shape[0])
  X = torch.from_numpy(X).to(device)

  output = model(X)
  _, predicted = torch.max(output, dim=1)

  tag = tags[predicted.item()]

  probs = torch.softmax(output, dim=1)
  prob = probs[0][predicted.item()]
  if prob.item() > 0.75:
      for intent in intents['intents']:
          if tag == intent["tag"]:
              return f"{bot_name}: {random.choice(intent['responses'])}"
  else:
      return f"{bot_name}: I do not understand..."
# Out:
# Let's chat! (type 'quit' to exit)

# %%
response = query('guide me to about Ministry of Foreign Affairs?')

# %%
response
# Out:
# 'Patrice: You can use this link https://t.co/yafuL0T3ND for more information'

# %%
# !pip install langdetect
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 4.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from langdetect) (1.15.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=45d89620822ddf7d9c029c3ba3ff63d6b0862d33c95ec60de1a346c590d08cb1
#   Stored in directory: /root/.cache/pip/wheels/13/c7/b0/79f66658626032e78fc1a83103690ef6797d551cb22e56e734
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %%
import requests
import json


class translator:
    api_url = "https://translate.googleapis.com/translate_a/single"
    client = "?client=gtx&dt=t"
    dt = "&dt=t"

    #fROM English to Kinyarwanda
    def translate(text : str , target_lang : str, source_lang : str):
        sl = f"&sl={source_lang}"
        tl = f"&tl={target_lang}"
        r = requests.get(translator.api_url+ translator.client + translator.dt + sl + tl + "&q=" + text)
        return json.loads(r.text)[0][0][0]

# %%
resp = translator.translate(text='Natafuta habari kuhusu Kenya', target_lang='eng', source_lang='swa')

# %%
resp
# Out:
# 'Natafuta habari kuhusu Kenya'

# %%
from langdetect import detect

def process_question(text : str):

  source_lang = detect(text)
  resp = translator.translate(text=text, target_lang='en', source_lang=source_lang)
  return resp, source_lang

def process_answer(text : str, source_lang):
  resp = translator.translate(text=text, target_lang=source_lang, source_lang='en')
  return resp

# %%
def process(QUESTION: str):
  USER_QUERY, SL = process_question(QUESTION) #Translate the original question into english and store the source lang
  RESPONSE = query(USER_QUERY) #Asking th chatbot question
  ORIGINAL_RESPONSE = process_answer(RESPONSE, SL)
  return ORIGINAL_RESPONSE

process("Natafuta habari kuhusu Kenya?")
# Out:
# 'Patrice: Unaweza kutumia kiungo hiki https://mfa.go.ke/business-deals-scholarships-and-trade-agreements-goodies-from-kenya-algeria-meeting/ kwa taarifa zaidi'
